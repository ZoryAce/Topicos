# %% [markdown]
# <a href="https://colab.research.google.com/github/ZoryAce/Topicos/blob/main/ENTREGA3/TALLER1/E1_TwitterNetworkAnalysis_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Integrantes:**
#
# -Luis Alejandro Garzón Ramirez
#
# -Zorayda Acevedo Jimenez
#
# -Yulieth Danitza Aguillón Ortega

# %% [markdown]
# # Twitter Network Analysis
# This notebook contains a social network analysis mainly executed with the library of NetworkX. In detail, this dataset consists of 'circles' (or 'lists') from Twitter. Twitter data was crawled from public sources. The dataset includes node features (profiles), circles, and ego networks. The dataset can be found at this link: [Stanford Twitter Dataset](https://snap.stanford.edu/data/ego-Twitter.html).

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from random import randint

# %matplotlib inline

# %% [markdown]
# ## Analysis
# The edges are loaded from the `data` folder and saved in a dataframe. Each edge is a new row and for each edge there is a `start_node` and an `end_node` column

# %%
twitter = pd.read_csv(
    "https://snap.stanford.edu/data/twitter_combined.txt.gz",
    compression="gzip",
    sep=" ",
    names=["start_node", "end_node"],
)
twitter = twitter.iloc[:80000]

# %% [markdown]
# The graph is created from the `twitter` dataframe of the edges:

# %%
G = nx.from_pandas_edgelist(twitter, "start_node", "end_node")

# %% [markdown]
# ## Visualizing the graph
#
# Let's start our exploration by visualizing the graph. Visualization plays a
# central role in exploratory data analysis to help get a qualitative feel for
# the data.
#
# Since we don't have any real sense of structure in the data, let's start by
# viewing the graph with `random_layout`, which is among the fastest of the layout
# functions.

# %%
fig, ax = plt.subplots(figsize=(15, 9))
ax.axis("off")
plot_options = {"node_size": 10, "with_labels": False, "width": 0.15}
nx.draw_networkx(G, pos=nx.random_layout(G), ax=ax, **plot_options)

# %% [markdown]
# Do we need more or less information (nodes or edges) from the graph to do the analysis? Let's check `spring_layout` and continue analysis...

# %%
pos = nx.spring_layout(G, iterations=15, seed=1721)
fig, ax = plt.subplots(figsize=(15, 9))
ax.axis("off")
nx.draw_networkx(G, pos=pos, ax=ax, **plot_options)

# %% [markdown]
# What other information can we extract from this network? ... (check graphs metrics)

# %% [markdown]
# # ***Atributos Básicos***

# %% [markdown]
# ### Número de Nodos

# %%
#Número de Nodos del Grafo de Twitter
G.number_of_nodes()
# Out:
# 4316

# %% [markdown]
# ###Número de Vértices

# %%
#Número de vértices del grafo de Twitter
G.number_of_edges()
# Out:
# 58270

# %% [markdown]
# ###Promedio de Grados de los Nodos
#
# En promedio, los nodos del grafo de Twitter contienen alrededor de 27 grados. Esto significa que cada nodo tienen promedio esta cantidad de conexiones con otros nodos del grafo (usuarios y seguidores)

# %%
np.mean([d for _, d in G.degree()])
# Out:
# np.float64(27.00185356811863)

# %% [markdown]
# ###Número de componentes
# El grafo de Twitter contiene 7 componentes principales. Esto significa que hay 7 'Subgrafos' con mayor conexión entre sí, lo que facilita las interacciones entre los 4316 usuarios. Mayor número de componentes haría que las interacciones o influencias dentro de la red no fueran tan fuertes

# %%
nx.number_connected_components(G)
# Out:
# 7

# %% [markdown]
# # ***Métricas de Integración***

# %% [markdown]
# ###Caminos mas cortos

# %%
shortest_path_lengths = dict(nx.all_pairs_shortest_path_length(G))

# %%
print(shortest_path_lengths.keys()) # identificar las claves del set
# Out:
# dict_keys([214328887, 34428380, 17116707, 28465635, 380580781, 18996905, 221036078, 153460275, 107830991, 17868918, 151338729, 222261763, 19705747, 88323281, 19933035, 149538028, 158419434, 17434613, 153226312, 364971269, 100581193, 279787626, 113058991, 69592091, 187773078, 406628822, 262802533, 460282402, 280935165, 437804658, 27633075, 285312927, 131613362, 17675120, 394263193, 254839786, 204317520, 21548772, 67864340, 172883064, 270449528, 297801196, 8088112, 14925700, 124528830, 307458983, 160237722, 220368467, 54228724, 206923844, 103598216, 207594668, 21146135, 451250774, 314316607, 6581292, 31331740, 196327549, 225444667, 274153775, 35415466, 72818790, 324201646, 40981798, 430268163, 88097807, 276308596, 358775055, 15023872, 16870853, 70492333, 430313102, 299715516, 35359596, 276577539, 248883350, 157829215, 107511013, 22462180, 258140947, 200559228, 19493072, 123371682, 461410856, 31414569, 37699718, 117901353, 117674417, 231238695, 56860418, 43003845, 413275344, 259842341, 400689940, 26929220, 35148062, 166214735, 57490887, 148519842, 15150609, 17759158, 83943787, 283306479, 125120339, 220068522, 155661154, 195475105, 134940306, 115221382, 368018677, 439788025, 262340283, 116498875, 257236842, 128721580, 463952369, 254610699, 247741328, 226629405, 529007327, 94621855, 83417972, 236184723, 197504076, 86221475, 222411742, 250178329, 292598082, 145845459, 29911100, 294752666, 27077521, 163238842, 133055665, 238201669, 260769396, 288485704, 229425177, 252770012, 121533789, 203338499, 213777144, 46209291, 46831674, 18951737, 239144776, 8163442, 28019653, 447688115, 16503181, 109740608, 116036694, 179138862, 276706356, 236143101, 333161611, 19358562, 226165839, 33612973, 37270037, 49104918, 83032174, 55033682, 170460311, 152388029, 112939321, 265077741, 261447035, 120599128, 186212304, 57828817, 250340951, 59588845, 2367911, 74107696, 477094958, 233248636, 86799233, 17627996, 30971165, 271602109, 81446304, 282206645, 31317273, 204140367, 189875309, 170167167, 45333725, 222090651, 93224416, 355823615, 309782398, 253091523, 349413327, 375317198, 31246395, 200884513, 312284236, 260705759, 43640117, 236026868, 95260836, 63941463, 83155222, 451493376, 73738774, 100052945, 21272026, 33806113, 9695312, 272173354, 41472982, 287915525, 105259389, 31457243, 102765423, 273149543, 53222305, 215787132, 375228586, 72680406, 11259362, 16216637, 767809, 30690708, 5992502, 17859804, 83876527, 19681661, 15465769, 22689667, 195409031, 57261575, 4126501, 22558481, 18109441, 60607157, 25615305, 16877939, 21734241, 46073276, 166002579, 6463042, 96770886, 7712232, 99211591, 23930272, 37977732, 16858804, 44436825, 28359405, 9973842, 451331227, 55113, 124746917, 41048052, 14677919, 203827751, 10075442, 17342842, 17477343, 56318573, 111615736, 83529586, 9503302, 5533902, 14551276, 17870886, 98976495, 22200888, 88974843, 16967011, 171145913, 163937752, 21742517, 113415132, 79797834, 18758940, 138549366, 19230869, 84111527, 50944856, 117998529, 23150071, 14169740, 38718720, 93906304, 6127252, 20757640, 17902348, 59557446, 27703441, 23484510, 792998, 18344173, 20583098, 55019225, 2705, 557196973, 23483324, 21074641, 52073562, 30486243, 174118650, 25835874, 17293897, 349256925, 258681133, 454423088, 22879382, 155613846, 35476618, 137355085, 30204310, 291476217, 236575672, 82030021, 17037417, 28149277, 111164068, 29514951, 94918917, 131601987, 159629146, 90722891, 90779436, 22784458, 191620115, 15999863, 146556805, 118811608, 95980722, 104155395, 51477206, 101903164, 14683518, 34805698, 176872879, 28144741, 37876253, 293353298, 239257866, 14876672, 486930916, 101859065, 263907906, 23152989, 345707398, 203623462, 61065794, 301695120, 102364313, 211670208, 37008705, 112819301, 352035443, 250849104, 19153742, 161788974, 147946019, 54581743, 235163686, 22440364, 54611487, 34507480, 243836182, 164422299, 27772095, 22592948, 328158079, 143838260, 58309829, 135268094, 222802532, 23375688, 25970331, 19383317, 230505689, 100318079, 206416476, 15460081, 20271494, ...

# %%
# Se toman dos nodos al azar para verificar el camino mas corto
shortest_path_lengths[214328887][221036078]
# Out:
# 1

# %% [markdown]
# En promedio de todo el grafo, para que cada nodo pueda estar conectado con otro, existen alrededor de 4.8 nodos de distancia entre sí.

# %%
average_path_lengths = [
    np.mean(list(spl.values())) for spl in shortest_path_lengths.values()
]
# promedio de los valores de camino más corto
np.mean(average_path_lengths)
# Out:
# np.float64(4.837700405033223)

# %%
print(nx.is_connected(G))  # Verificar si el grafo está conectado
# Out:
# False

# %% [markdown]
# Dado que el grafo no está conectado completamente entre sí, se hará un análisis sobre uno de los componentes principales.

# %%
# Encontrar el componente más grande
largest_cc = max(nx.connected_components(G), key=len)
# Crear un subgrafo
G_largest = G.subgraph(largest_cc)

# %%
# Diámetro del subgrafo
diameter = max(nx.eccentricity(G_largest, sp=shortest_path_lengths).values())
print(diameter)
# Out:
# 16

# %% [markdown]
# Lo anterior significa que para que cualquier nodo logre conectarse con otro, debería atravesar máximo 16 nodos de distancia.

# %%
# Visualizar la distribución de los caminos mas cortos de todo el grafo
path_lengths = np.zeros(diameter + 1, dtype=int)

for pls in shortest_path_lengths.values():
    pl, cnts = np.unique(list(pls.values()), return_counts=True)
    path_lengths[pl] += cnts

freq_percent = 100 * path_lengths[1:] / path_lengths[1:].sum()

fig, ax = plt.subplots(figsize=(15, 8))
ax.bar(np.arange(1, diameter + 1), height=freq_percent)
ax.set_title(
    "Distribución del camino más corto en G", fontdict={"size": 20}, loc="center"
)
ax.set_xlabel("Camino más Corto", fontdict={"size": 12})
ax.set_ylabel("Frecuencia (%)", fontdict={"size": 12})
# Out:
# Text(0, 0.5, 'Frecuencia (%)')

# %% [markdown]
# Como se observa en la gráfica y según las métricas anteriores, la mayor distancia promedio entre nodos como camino mas corto se encuentra entre 2 y 8 nodos. De igual manera, para el subgrafo que es el componente mas grande, no hay caminos mayores a 16 nodos.

# %% [markdown]
# ###Densidad

# %%
nx.density(G)
# Out:
# 0.0062576717423218145

# %% [markdown]
# El resultado indica que, teniendo todas las métricas anteriores en cuenta, que la red tiene conexiones débiles e interacción menos frecuente (esto se puede ver en el promedio de grados del grafo). Esto implica que las interacciones realmente no se generan con facilidad y que un usuario (influenciador) no logrará generar influir significativamente en la porción mayoritaria de la red.

# %% [markdown]
# ###Eficiencia

# %%
round(nx.global_efficiency(G),2)
# Out:
# 0.22

# %% [markdown]
# Como complemento de la densidad, la eficiencia nos muestra que con un 0.22 de valor, que la red no tiene una conexión alta entre sí. La información no fluye con facilidad entre todos los nodos de la red.

# %% [markdown]
# ###Puentes

# %%
nx.has_bridges(G)
# Out:
# True

# %%
bridges = list(nx.bridges(G))
len(bridges)
# Out:
# 209

# %% [markdown]
# El grafo contiene 209 puentes en todo el grafo, es decir, vértices que si son eliminados, generan nuevos componentes.

# %%
local_bridges = list(nx.local_bridges(G, with_span=False))
len(local_bridges)
# Out:
# 987

# %% [markdown]
# El grafo contiene 987 puentes locales, es decir, vértices que existen solo entre un par de nodos único. Sginifica que no estos nodos no tienen vecinos en común salvo sí mismos.

# %%
plt.figure(figsize=(15, 8))
nx.draw_networkx(G, pos=pos, node_size=10, with_labels=False, width=0.20)
nx.draw_networkx_edges(
    G, pos, edgelist=local_bridges, width=0.5, edge_color="lawngreen"
)  # green color for local bridges
nx.draw_networkx_edges(
    G, pos, edgelist=bridges, width=0.5, edge_color="y"
)  # red color for bridges
plt.axis("off")
# Out:
# (np.float64(-0.6459476724267006),
#  np.float64(1.1564022675156593),
#  np.float64(-1.0558947339653968),
#  np.float64(0.7013561144471169))

# %% [markdown]
# # ***Métricas de Segregación***

# %% [markdown]
# ###Clustering

# %%
nx.average_clustering(G)
# Out:
# 0.4949716847236492

# %%
plt.figure(figsize=(15, 8))
plt.hist(nx.clustering(G).values(), bins=50)
plt.title("Histograma de Coeficiente de Clustering", fontdict={"size": 20}, loc="center")
plt.xlabel("Coeficiente de Clustering", fontdict={"size": 12})
plt.ylabel("Conteo", fontdict={"size": 12})
# Out:
# Text(0, 0.5, 'Conteo')

# %% [markdown]
# A partir del histograma, podemos observar que la mayor proporción de los nodos del grafo de Twitter cuentan con un Coeficiente de Clustering entre los valores 0.3 y 0.7. El promedio se sitúa en 0.49.
#
# Entre más alto sea el valor del coeficiente, mayor tendencia tendrá el nodo a formar agrupaciones. En este caso observamos que el grafo de Twitter no es completamente segregado, pero no es suficientemente conectado. Lo anterior ya se había visto con medidas anteriores.
#
# Destaca que un número alto de nodos tienen un valor de coeficiente bajo, lo cual demuestra que en general las interacciones y uniones en este grafo no se dan sencillamente y hay tendencia a tener varios componentes.

# %%
# Número total de triángulos entre nodos del grafo
triangles_per_node = list(nx.triangles(G).values())
sum(triangles_per_node) / 3
# Out:
# 465759.0

# %%
np.mean(triangles_per_node)
# Out:
# np.float64(323.7435125115848)

# %% [markdown]
# En promedio, un nodo de del grafo participa en al rededor de 323 triángulos.

# %%
np.median(triangles_per_node)
# Out:
# np.float64(71.0)

# %% [markdown]
# La media de triángulos en los que participa un nodo del grafo es de 71.

# %% [markdown]
# Lo anterior significa que hay nodos con altos valores de conexiones, sin embargo, al menos un 50% de los nodos no participa en mas de 71 triángulos.
#
# De esta forma, podemos ver que la estructura de comunidades del grafo no es suficientemente fuerte para lograr conexiones entre todos los usuarios. En otras palabras, los usuarios no logran interactuar con facilidad con muchos de los usuarios del resto de Twitter.

# %% [markdown]
# ###Transitividad

# %%
nx.transitivity(G)
# Out:
# 0.4117694383246281

# %% [markdown]
# La transitividad tiene un valor de 0.41. Significa que dos nodos conectados entre sí tienen una probabilidad de 41% de generar una conexión con un tercer nodo.

# %% [markdown]
# ###Comunidades de Redes

# %%
colors = {}
counter = 0
for com in nx.community.label_propagation_communities(G):
    color = "#%06X" % randint(0, 0xFFFFFF)
    counter += 1
    for node in com:
        colors[node] = color
print(counter)
# Out:
# 88

# %% [markdown]
# Se detectan 88 comunidades en la red, es decir, grupos de nodos que tienen conexiones mas fuerte entre sí que con nodos de otro grupo.

# %%
color_list = [colors[node] for node in G.nodes()]

plt.figure(figsize=(15, 9))
plt.axis("off")
nx.draw_networkx(
    G, pos=pos, node_size=10, with_labels=False, width=0.15, node_color=color_list
)

# %%
 colors = {}  # Diccionario para almacenar el color de cada nodo en el subgrafo
for com in nx.community.asyn_fluidc(G_largest, 10, seed=0):
    color = "#%06X" % randint(0, 0xFFFFFF)  # Generar color aleatorio
    for node in com:
        colors[node] = color  # Asignar el color a cada nodo en el diccionario

# %% [markdown]
# Hacemos una énfasis en 10 comunidades para visualizarlas cada una con diferentes colores.

# %%
color_list = [colors[node] for node in G_largest.nodes()]

plt.figure(figsize=(15, 9))
plt.axis("off")
nx.draw_networkx(
    G_largest, pos=pos, node_size=10, with_labels=False, width=0.10, node_color=color_list
)

# %% [markdown]
# ###Modularidad

# %%
import networkx.algorithms.community as nx_comm

# %%
print(nx_comm.modularity(G, nx_comm.label_propagation_communities(G)))
# Out:
# 0.8248668687208482

# %% [markdown]
# # ***Métricas de Centralidad***

# %% [markdown]
# ###Grados de Centralidad

# %%
nx.centrality.degree_centrality(G)
# Out:
# {214328887: 0.023174971031286212,
#  34428380: 0.056315179606025494,
#  17116707: 0.017149478563151795,
#  28465635: 0.027578215527230592,
#  380580781: 0.014600231749710313,
#  18996905: 0.028041714947856317,
#  221036078: 0.015063731170336037,
#  153460275: 0.008111239860950173,
#  107830991: 0.01993047508690614,
#  17868918: 0.02618771726535342,
#  151338729: 0.027346465816917728,
#  222261763: 0.018308227114716108,
#  19705747: 0.01205098493626883,
#  88323281: 0.025724217844727695,
#  19933035: 0.00996523754345307,
#  149538028: 0.020162224797219002,
#  158419434: 0.024797219003476246,
#  17434613: 0.007184241019698725,
#  153226312: 0.027809965237543453,
#  364971269: 0.007879490150637311,
#  100581193: 0.025028968713789106,
#  279787626: 0.0287369640787949,
#  113058991: 0.011587485515643106,
#  69592091: 0.02294322132097335,
#  187773078: 0.02526071842410197,
#  406628822: 0.016917728852838935,
#  262802533: 0.01205098493626883,
#  460282402: 0.0050984936268829665,
#  280935165: 0.01993047508690614,
#  437804658: 0.008342989571263035,
#  27633075: 0.026651216685979143,
#  285312927: 0.012514484356894553,
#  131613362: 0.020162224797219002,
#  17675120: 0.006257242178447277,
#  394263193: 0.023174971031286212,
#  254839786: 0.02526071842410197,
#  204317520: 0.023406720741599073,
#  21548772: 0.009038238702201622,
#  67864340: 0.019003476245654693,
#  172883064: 0.02108922363847045,
#  270449528: 0.02526071842410197,
#  297801196: 0.013441483198146002,
#  8088112: 0.023406720741599073,
#  14925700: 0.010660486674391657,
#  124528830: 0.01853997682502897,
#  307458983: 0.02085747392815759,
#  160237722: 0.015990730011587486,
#  220368467: 0.016222479721900347,
#  54228724: 0.008342989571263035,
#  206923844: 0.021320973348783315,
#  103598216: 0.020162224797219002,
#  207594668: 0.0011587485515643105,
#  21146135: 0.005793742757821553,
#  451250774: 0.021552723059096175,
#  314316607: 0.02108922363847045,
#  6581292: 0.01205098493626883,
#  31331740: 0.025955967555040555,
#  196327549: 0.01738122827346466,
#  225444667: 0.016917728852838935,
#  274153775: 0.023638470451911937,
#  35415466: 0.010660486674391657,
#  72818790: 0.02085747392815759,
#  324201646: 0.0018539976825028969,
#  40981798: 0.06257242178447277,
#  430268163: 0.01853997682502897,
#  88097807: 0.021320973348783315,
#  276308596: 0.020162224797219002,
#  358775055: 0.02549246813441483,
#  15023872: 0.009269988412514484,
#  16870853: 0.0025492468134414832,
#  70492333: 0.014600231749710313,
#  430313102: 0.01089223638470452,
#  299715516: 0.006488991888760139,
#  35359596: 0.0037079953650057938,
#  276577539: 0.013673232908458864,
#  248883350: 0.01668597914252607,
#  157829215: 0.02526071842410197,
#  107511013: 0.0039397450753186555,
#  22462180: 0.05608342989571263,
#  258140947: 0.020625724217844726,
#  200559228: 0.015758980301274622,
#  19493072: 0.023870220162224797,
#  123371682: 0.022247972190034764,
#  461410856: 0.024565469293163385,
#  31414569: 0.015990730011587486,
#  37699718: 0.011355735805330244,
#  117901353: 0.00996523754345307,
#  117674417: 0.023174971031286212,
#  231238695: 0.012977983777520278,
#  56860418: 0.02294322132097335,
#  43003845: 0.0593279258400927,
#  413275344: 0.004634994206257242,
#  259842341: 0.025028968713789106,
#  400689940: 0.013673232908458864,
#  26929220: 0.023406720741599073,
#  35148062: 0.004634994206257242,
#  166214735: 0.012514484356894553,
#  57490887: 0.0220162224797219,
#  148519842: 0.006257242178447277,
#  15150609: 0.00996523754345307,
#  17759158: 0.012746234067207415,
#  83943787: 0.028041714947856317,
#  283306479: 0.01738122827346466,
#  125120339: 0.011819235225955968,
#  220068522: 0.00996523754345307,
#  155661154: 0.010428736964078795,
#  195475105: 0.025724217844727695,
#  134940306: 0.02641946697566628,
#  115221382: 0.007184241019698725,
#  368018677: 0.0009269988412514484,
#  439788025: 0.01993047508690614,
#  262340283: 0.01738122827346466,
#  116498875: 0.016222479721900347,
#  257236842: 0.015527230590961762,
#  128721580: 0.0006952491309385864,
#  463952369: 0.025028968713789106,
#  254610699: 0.002317497103128621,
#  247741328: 0.005330243337195829,
#  226629405: 0.01436848203939745,
#  529007327: 0.011355735805330244,
#  94621855: 0.005793742757821553,
#  83417972: 0.018771726535341832,
#  236184723: 0.0220162224797219,
#  197504076: 0.01853997682502897,
#  86221475: 0.01761297798377752,
#  222411742: 0.00764774044032445,
#  250178329: 0.009501738122827346,
#  292598082: 0.009733487833140209,
#  145845459: 0.013441483198146002,
#  29911100: 0.012282734646581693,
#  294752666: 0.011819235225955968,
#  27077521: 0.007879490150637311,
#  163238842: 0.007184241019698725,
#  133055665: 0.02178447276940904,
#  238201669: 0.009269988412514484,
#  260769396: 0.005561993047508691,
#  288485704: 0.013673232908458864,
#  229425177: 0.01436848203939745,
#  252770012: 0.011123986095017382,
#  121533789: 0.02085747392815759,
#  203338499: 0.016917728852838935,
#  213777144: 0.01668597914252607,
#  46209291: 0.025724217844727695,
#  46831674: 0.0037079953650057938,
#  18951737: 0.012282734646581693,
#  239144776: 0.008574739281575898,
#  8163442: 0.009733487833140209,
#  28019653: 0.0025492468134414832,
#  447688115: 0.01436848203939745,
#  16503181: 0.002317497103128621,
#  109740608: 0.01205098493626883,
#  116036694: 0.02526071842410197,
#  179138862: 0.004171494785631518,
#  276706356: 0.023638470451911937,
#  236143101: 0.011587485515643106,
#  333161611: 0.0039397450753186555,
#  19358562: 0.020393974507531866,
#  226165839: 0.0032444959443800694,
#  33612973: 0.004634994206257242,
#  37270037: 0.006257242178447277,
#  49104918: 0.00440324449594438,
#  83032174: 0.0025492468134414832,
#  55033682: 0.006025492468134415,
#  170460311: 0.00764774044032445,
#  152388029: 0.008574739281575898,
#  112939321: 0.013673232908458864,
#  265077741: 0.011587485515643106,
#  261447035: 0.005793742757821553,
#  120599128: 0.0025492468134414832,
#  186212304: 0.009038238702201622,
#  57828817: 0.0030127462340672076,
#  250340951: 0.00880648899188876,
#  59588845: 0.006720741599073001,
#  2367911: 0.019466975666280417,
#  74107696: 0.016222479721900347,
#  477094958: 0.002085747392815759,
#  233248636: 0.010196987253765933,
#  86799233: 0.0018539976825028969,
#  17627996: 0.002085747392815759,
#  30971165: 0.007879490150637311,
#  271602109: 0.0030127462340672076,
#  81446304: 0.002085747392815759,
#  282206645: 0.007184241019698725,
#  31317273: 0.0016222479721900347,
#  204140367: 0.022711471610660488,
#  189875309: 0.006952491309385863,
#  170167167: 0.002317497103128621,
#  45333725: 0.0025492468134414832,
#  222090651: 0.0037079953650057938,
#  93224416: 0.002085747392815759,
#  355823615: 0.005793742757821553,
#  309782398: 0.0016222479721900347,
#  253091523: 0.004634994206257242,
#  349413327: 0.004171494785631518,
#  375317198: 0.013673232908458864,
#  31246395: 0.0032444959443800694,
#  200884513: 0.0013904982618771727,
#  312284236: 0.0050984936268829665,
#  260705759: 0.002085747392815759,
#  43640117: 0.0037079953650057938,
#  236026868: 0.007879490150637311,
#  95260836: 0.005793742757821553,
#  63941463: 0.002317497103128621,
#  83155222: 0.0027809965237543454,
#  451493376: 0.0009269988412514484,
#  73738774: 0.0037079953650057938,
#  100052945: 0.0016222479721900347,
#  21272026: 0.0034762456546929316,
#  33806113: 0.0016222479721900347,
#  9695312: 0.0025492468134414832,
#  272173354: 0.0018539976825028969,
#  41472982: 0.0032444959443800694,
#  287915525: 0.0018539976825028969,
#  105259389: 0.0011587485515643105,
#  31457243: 0.0025492468134414832,
#  102765423: 0.0013904982618771727,
#  273149543: 0.004866743916570104,
#  53222305: 0.002317497103128621,
#  215787132: 0.0013904982618771727,
#  375228586: 0.0004634994206257242,
#  72680406: 0.0039397450753186555,
#  11259362: 0.006488991888760139,
#  16216637: 0.0050984936268829665,
#  767809: 0.0013904982618771727,
#  30690708: 0.0016222479721900347,
#  5992502: 0.00440324449594438,
#  17859804: 0.005330243337195829,
#  83876527: 0.0074159907300115875,
#  19681661: 0.004634994206257242,
#  15465769: 0.0025492468134414832,
#  22689667: 0.004634994206257242,
#  195409031: 0.0030127462340672076,
#  57261575: 0.0032444959443800694,
#  4126501: 0.005330243337195829,
#  22558481: 0.0018539976825028969,
#  18109441: 0.0050984936268829665,
#  60607157: 0.0009269988412514484,
#  25615305: 0.006720741599073001,
#  16877939: 0.0030127462340672076,
#  21734241: 0.0032444959443800694,
#  46073276: 0.0074159907300115875,
#  166002579: 0.0004634994206257242,
#  6463042: 0.005561993047508691,
#  96770886: 0.0027809965237543454,
#  7712232: 0.0018539976825028969,
#  99211591: 0.0037079953650057938,
#  23930272: 0.0030127462340672076,
#  37977732: 0.00440324449594438,
#  16858804: 0.002085747392815759,
#  44436825: 0.005330243337195829,
#  28359405: 0.0032444959443800694,
#  9973842: 0.008574739281575898,
#  451331227: 0.0027809965237543454,
#  55113: 0.00440324449594438,
#  124746917: 0.0030127462340672076,
#  41048052: 0.0027809965237543454,
#  14677919: 0.007184241019698725,
#  203827751: 0.0050984936268829665,
#  10075442: 0.004171494785631518,
#  17342842: 0.005561993047508691,
#  17477343: 0.002085747392815759,
#  56318573: 0.0034762456546929316,
#  111615736: 0.0030127462340672076,
#  83529586: 0.0011587485515643105,
#  9503302: 0.0030127462340672076,
#  5533902: 0.0025492468134414832,
#  14551276: 0.005793742757821553,
#  17870886: 0.006025492468134415,
#  98976495: 0.0013904982618771727,
#  22200888: 0.006720741599073001,
#  88974843: 0.0018539976825028969,
#  16967011: 0.0016222479721900347,
#  171145913: 0.0037079953650057938,
#  163937752: 0.0039397450753186555,
#  21742517: 0.0032444959443800694,
#  113415132: 0.002085747392815759,
#  79797834: 0.006488991888760139,
#  18758940: 0.0025492468134414832,
#  138549366: 0.0034762456546929316,
#  19230869: 0.0016222479721900347,
#  84111527: 0.002085747392815759,
#  50944856: 0.0034762456546929316,
#  117998529: 0.0050984936268829665,
#  23150071: 0.0034762456546929316,
#  14169740: 0.0050984936268829665,
#  38718720: 0.0025492468134414832,
#  93906304: 0.0018539976825028969,
#  6127252: 0.002085747392815759,
#  20757640: 0.0030127462340672076,
#  17902348: 0.00440324449594438,
#  59557446: 0.0018539976825028969,
#  27703441: 0.002317497103128621,
#  23484510: 0.0013904982618771727,
#  792998: 0.002085747392815759,
#  18344173: 0.0006952491309385864,
#  20583098: 0.002085747392815759,
#  55019225: 0.0013904982618771727,
#  2705: 0.0027809965237543454,
#  557196973: 0.0004634994206257242,
#  23483324: 0.002317497103128621,
#  21074641: 0.0037079953650057938,
#  52073562: 0.0009269988412514484,
#  30486243: 0.0030127462340672076,
#  174118650: 0.0009269988412514484,
#  25835874: 0.0006952491309385864,
#  17293897: 0.0025492468134414832,
#  349256925: 0.0006952491309385864,
#  258681133: 0.0002317497103128621,
#  454423088: 0.0002317497103128621,
#  22879382: 0.0004634994206257242,
#  155613846: 0.0011587485515643105,
#  35476618: 0.0002317497103128621,
#  137355085: 0.0002317497103128621,
#  30204310: 0.0004634994206257242,
#  291476217: 0.0004634994206257242,
#  236575672: 0.002085747392815759,
#  82030021: 0.009269988412514484,
#  17037417: 0.0016222479721900347,
#  28149277: 0.0039397450753186555,
#  111164068: 0.0050984936268829665,
#  29514951: 0.009038238702201622,
#  94918917: 0.0013904982618771727,
#  131601987: 0.009733487833140209,
#  159629146: 0.0037079953650057938,
#  90722891: 0.0032444959443800694,
#  90779436: 0.006025492468134415,
#  22784458: 0.01320973348783314,
#  191620115: 0.0034762456546929316,
#  15999863: 0.0030127462340672076,
#  146556805: 0.002317497103128621,
#  118811608: 0.0027809965237543454,
#  95980722: 0.0032444959443800694,
#  104155395: 0.0030127462340672076,
#  51477206: 0.0018539976825028969,
#  101903164: 0.002085747392815759,
#  14683518: 0.00440324449594438,
#  34805698: 0.0016222479721900347,
#  176872879: 0.0027809965237543454,
#  28144741: 0.0013904982618771727,
#  37876253: 0.0009269988412514484,
#  293353298: 0.002085747392815759,
#  239257866: 0.0006952491309385864,
#  14876672: 0.005561993047508691,
#  486930916: 0.0009269988412514484,
#  101859065: 0.006488991888760139,
#  263907906: 0.0006952491309385864,
#  23152989: 0.004634994206257242,
#  345707398: 0.0002317497103128621,
#  203623462: 0.0030127462340672076,
#  61065794: 0.009269988412514484,
#  301695120: 0.005793742757821553,
#  102364313: 0.0050984936268829665,
#  211670208: 0.00880648899188876,
#  37008705: 0.00996523754345307,
#  112819301: 0.008342989571263035,
#  352035443: 0.004634994206257242,
#  250849104: 0.006257242178447277,
#  19153742: 0.0016222479721900347,
#  161788974: 0.004171494785631518,
#  147946019: 0.005330243337195829,
#  54581743: 0.0027809965237543454,
#  235163686: 0.0025492468134414832,
#  22440364: 0.009733487833140209,
#  54611487: 0.004171494785631518,
#  34507480: 0.009038238702201622,
#  243836182: 0.0039397450753186555,
#  164422299: 0.00764774044032445,
#  27772095: 0.009038238702201622,
#  22592948: 0.009501738122827346,
#  328158079: 0.005330243337195829,
#  143838260: 0.009501738122827346,
#  58309829: 0.007879490150637311,
#  135268094: 0.0030127462340672076,
#  222802532: 0.0018539976825028969,
#  23375688: 0.0074159907300115875,
#  25970331: 0.013904982618771726,
#  19383317: 0.006025492468134415,
#  230505689: 0.0016222479721900347,
#  100318079: 0.004634994206257242,
#  206416476: 0.006488991888760139,
#  15460081: 0.012282734646581693,
#  20271494: 0.004171494785631518,
#  169504184: 0.006952491309385863,
#  16824090: 0.0032444959443800694,
#  115525090: 0.004634994206257242,
#  29654458: 0.0030127462340672076,
#  26649453: 0.0039397450753186555,
#  14425825: 0.0074159907300115875,
#  421412483: 0.007184241019698725,
#  243227325: 0.005793742757821553,
#  240944206: 0.0034762456546929316,
#  63808966: 0.00880648899188876,
#  16895295: 0.0032444959443800694,
#  243273954: 0.005330243337195829,
#  226516599: 0.0074159907300115875,
#  163274846: 0.0013904982618771727,
#  111990504: 0.0013904982618771727,
#  408060505: 0.004171494785631518,
#  309765553: 0.002317497103128621,
#  27090278: 0.002085747392815759,
#  225488317: 0.0030127462340672076,
#  148081553: 0.004866743916570104,
#  197090502: 0.004171494785631518,
#  69373005: 0.0032444959443800694,
#  48504743: 0.0013904982618771727,
#  302936475: 0.002317497103128621,
#  480595611: 0.00440324449594438,
#  40968863: 0.00440324449594438,
#  34270956: 0.0011587485515643105,
#  2883841: 0.0018539976825028969,
#  325054079: 0.002085747392815759,
#  126470482: 0.0004634994206257242,
#  181288376: 0.006720741599073001,
#  250988604: 0.0011587485515643105,
#  171704225: 0.002317497103128621,
#  158526208: 0.0025492468134414832,
#  192023970: 0.005330243337195829,
#  339373057: 0.0025492468134414832,
#  193593048: 0.0016222479721900347,
#  176222605: 0.0004634994206257242,
#  244719623: 0.0016222479721900347,
#  335678635: 0.0002317497103128621,
#  79817691: 0.0018539976825028969,
#  109698612: 0.0006952491309385864,
#  208105146: 0.0009269988412514484,
#  25592034: 0.0009269988412514484,
#  333011515: 0.0006952491309385864,
#  258490941: 0.0013904982618771727,
#  342221618: 0.0002317497103128621,
#  32032000: 0.015758980301274622,
#  19507713: 0.012514484356894553,
#  16583672: 0.006488991888760139,
#  35918787: 0.006488991888760139,
#  20803125: 0.006952491309385863,
#  311776211: 0.0037079953650057938,
#  16079941: 0.007184241019698725,
#  7861312: 0.038702201622247974,
#  7860742: 0.031054461181923523,
#  9955652: 0.004171494785631518,
#  462541005: 0.00880648899188876,
#  20747741: 0.015990730011587486,
#  17047105: 0.012282734646581693,
#  23559552: 0.006257242178447277,
#  20106852: 0.008342989571263035,
#  51246108: 0.008342989571263035,
#  20637608: 0.01645422943221321,
#  434725454: 0.0027809965237543454,
#  18927441: 0.046813441483198145,
#  18666844: 0.016917728852838935,
#  15666380: 0.03221320973348783,
#  365014160: 0.006257242178447277,
#  21158690: 0.020625724217844726,
#  15271920: 0.008111239860950173,
#  16786977: 0.008574739281575898,
#  373018050: 0.009501738122827346,
#  369586333: 0.012282734646581693,
#  96747353: 0.008111239860950173,
#  16799897: 0.009733487833140209,
#  51162310: 0.006488991888760139,
#  18130749: 0.005561993047508691,
#  317846921: 0.007184241019698725,
#  130897520: 0.01761297798377752,
#  363426409: 0.016222479721900347,
#  438460947: 0.00764774044032445,
#  58714972: 0.01320973348783314,
#  16663695: 0.0011587485515643105,
#  47799910: 0.002085747392815759,
#  31808762: 0.01853997682502897,
#  14888584: 0.011123986095017382,
#  315338495: 0.01320973348783314,
#  352226153: 0.015527230590961762,
#  300599613: 0.010660486674391657,
#  16909832: 0.012514484356894553,
#  167744987: 0.002085747392815759,
#  362286999: 0.006257242178447277,
#  126099878: 0.011587485515643106,
#  422066630: 0.00996523754345307,
#  191638793: 0.006952491309385863,
#  16038438: 0.03568945538818077,
#  390811153: 0.002085747392815759,
#  794186: 0.0039397450753186555,
#  394216985: 0.0050984936268829665,
#  17105214: 0.012514484356894553,
#  126042901: 0.007879490150637311,
#  7384432: 0.0037079953650057938,
#  95820486: 0.008574739281575898,
#  62050341: 0.015990730011587486,
#  15343773: 0.007879490150637311,
#  19049747: 0.015527230590961762,
#  167010482: 0.007184241019698725,
#  60101131: 0.0027809965237543454,
#  299715714: 0.014136732329084589,
#  7079062: 0.00996523754345307,
#  88501703: 0.01089223638470452,
#  18069427: 0.0034762456546929316,
#  405323682: 0.011819235225955968,
#  404376053: 0.010660486674391657,
#  193059216: 0.00764774044032445,
#  20747847: 0.03406720741599073,
#  7377812: 0.015758980301274622,
#  172959279: 0.011819235225955968,
#  15439395: 0.01853997682502897,
#  14824849: 0.016222479721900347,
#  110481357: 0.006257242178447277,
#  212018296: 0.004171494785631518,
#  15661871: 0.00764774044032445,
#  17092862: 0.0032444959443800694,
#  224809136: 0.011587485515643106,
#  223247584: 0.009733487833140209,
#  14111650: 0.006720741599073001,
#  14589257: 0.017844727694090384,
#  310087940: 0.005561993047508691,
#  18501326: 0.009501738122827346,
#  243058696: 0.00996523754345307,
#  18781900: 0.005793742757821553,
#  306472866: 0.014831981460023175,
#  344334227: 0.011587485515643106,
#  7453822: 0.0074159907300115875,
#  357268791: 0.008111239860950173,
#  8207762: 0.01089223638470452,
#  308324295: 0.01436848203939745,
#  16894839: 0.0152954808806489,
#  280725732: 0.009269988412514484,
#  26841335: 0.013673232908458864,
#  16218063: 0.004171494785631518,
#  467658266: 0.009269988412514484,
#  8715652: 0.0013904982618771727,
#  116511302: 0.008342989571263035,
#  33087222: 0.011355735805330244,
#  40791597: 0.0004634994206257242,
#  17158189: 0.00440324449594438,
#  18445879: 0.006257242178447277,
#  19415126: 0.00764774044032445,
#  25495625: 0.005330243337195829,
#  4893411: 0.006025492468134415,
#  7081402: 0.020393974507531866,
#  143244854: 0.0050984936268829665,
#  23691649: 0.0025492468134414832,
#  337131276: 0.008574739281575898,
#  127569781: 0.014831981460023175,
#  20661527: 0.01320973348783314,
#  14464369: 0.013904982618771726,
#  14424667: 0.009733487833140209,
#  15643370: 0.008574739281575898,
#  22643137: 0.004634994206257242,
#  46241448: 0.006952491309385863,
#  22857385: 0.010428736964078795,
#  16150457: 0.0037079953650057938,
#  15913: 0.055851680185399766,
#  28521141: 0.00880648899188876,
#  18602163: 0.002317497103128621,
#  43662236: 0.013673232908458864,
#  40340464: 0.010428736964078795,
#  351671009: 0.016222479721900347,
#  10350: 0.015758980301274622,
#  24591819: 0.00996523754345307,
#  59877557: 0.015527230590961762,
#  179278975: 0.006720741599073001,
#  15029953: 0.002317497103128621,
#  114563370: 0.013904982618771726,
#  15575251: 0.026882966396292004,
#  123678437: 0.006257242178447277,
#  18849313: 0.0039397450753186555,
#  16908436: 0.008111239860950173,
#  18488495: 0.0032444959443800694,
#  18125335: 0.007184241019698725,
#  9199472: 0.008342989571263035,
#  14311802: 0.010196987253765933,
#  756379: 0.00764774044032445,
#  14412605: 0.004634994206257242,
#  520027894: 0.0034762456546929316,
#  15665127: 0.011123986095017382,
#  1183041: 0.03476245654692932,
#  15758036: 0.009038238702201622,
#  19521118: 0.0034762456546929316,
#  18444530: 0.004866743916570104,
#  87759396: 0.011355735805330244,
#  28202547: 0.014600231749710313,
#  14165096: 0.009733487833140209,
#  1065921: 0.016222479721900347,
#  20273398: 0.024797219003476246,
#  16626187: 0.0074159907300115875,
#  19489341: 0.0016222479721900347,
#  6572452: 0.002085747392815759,
#  43219574: 0.006257242178447277,
#  294430454: 0.01738122827346466,
#  6068612: 0.004866743916570104,
#  14326003: 0.0006952491309385864,
#  31067157: 0.0152954808806489,
#  769584: 0.0037079953650057938,
#  33035636: 0.0018539976825028969,
#  121637129: 0.0034762456546929316,
#  34455805: 0.0013904982618771727,
#  468094034: 0.0032444959443800694,
#  23831909: 0.0025492468134414832,
#  14303746: 0.01205098493626883,
#  21076522: 0.006257242178447277,
#  16956955: 0.004171494785631518,
#  358553967: 0.013441483198146002,
#  274149738: 0.008342989571263035,
#  50557241: 0.00764774044032445,
#  333709376: 0.008111239860950173,
#  66561957: 0.00440324449594438,
#  16098603: 0.038702201622247974,
#  48370736: 0.009501738122827346,
#  187366802: 0.0025492468134414832,
#  34170312: 0.0037079953650057938,
#  283306509: 0.006952491309385863,
#  5980142: 0.0027809965237543454,
#  15863699: 0.0009269988412514484,
#  17759701: 0.021320973348783315,
#  14050306: 0.0018539976825028969,
#  23742474: 0.0011587485515643105,
#  16536215: 0.0030127462340672076,
#  18819743: 0.005793742757821553,
#  395395198: 0.0013904982618771727,
#  20015787: 0.0025492468134414832,
#  681813: 0.005330243337195829,
#  56768257: 0.0016222479721900347,
#  15359658: 0.002317497103128621,
#  41262929: 0.0037079953650057938,
#  520809979: 0.006952491309385863,
#  18959811: 0.0006952491309385864,
#  55656369: 0.0030127462340672076,
#  125540746: 0.0006952491309385864,
#  3462421: 0.005330243337195829,
#  43275782: 0.0002317497103128621,
#  18709570: 0.00440324449594438,
#  16583999: 0.004171494785631518,
#  167552021: 0.0016222479721900347,
#  22924257: 0.0016222479721900347,
#  31892440: 0.0004634994206257242,
#  75193883: 0.004171494785631518,
#  14326533: 0.004866743916570104,
#  23390284: 0.0030127462340672076,
#  17865810: 0.0002317497103128621,
#  332375645: 0.004171494785631518,
#  7385102: 0.0004634994206257242,
#  43115008: 0.002317497103128621,
#  254792310: 0.0006952491309385864,
#  89728799: 0.0011587485515643105,
#  14144060: 0.0006952491309385864,
#  101496725: 0.0006952491309385864,
#  405056781: 0.0018539976825028969,
#  21308602: 0.0013904982618771727,
#  17794560: 0.0006952491309385864,
#  54298095: 0.0013904982618771727,
#  17983020: 0.0002317497103128621,
#  74229529: 0.0011587485515643105,
#  26547954: 0.0011587485515643105,
#  194889318: 0.0016222479721900347,
#  118599144: 0.0004634994206257242,
#  120867457: 0.0002317497103128621,
#  102434415: 0.0004634994206257242,
#  16891273: 0.0002317497103128621,
#  350939079: 0.0016222479721900347,
#  323405569: 0.0011587485515643105,
#  109065990: 0.002085747392815759,
#  106708586: 0.0025492468134414832,
#  316797838: 0.0037079953650057938,
#  374949999: 0.0027809965237543454,
#  52216611: 0.0039397450753186555,
#  50453498: 0.0011587485515643105,
#  20471349: 0.020162224797219002,
#  497434530: 0.004634994206257242,
#  18825961: 0.007879490150637311,
#  308522948: 0.0034762456546929316,
#  17861062: 0.0009269988412514484,
#  423662810: 0.0011587485515643105,
#  433691110: 0.0013904982618771727,
#  28125177: 0.0025492468134414832,
#  16589206: 0.0025492468134414832,
#  64643056: 0.0016222479721900347,
#  16151999: 0.0004634994206257242,
#  15838599: 0.0011587485515643105,
#  515602819: 0.0016222479721900347,
#  43611927: 0.0016222479721900347,
#  55949049: 0.0016222479721900347,
#  294198566: 0.013673232908458864,
#  290656947: 0.00440324449594438,
#  324546502: 0.0034762456546929316,
#  285727668: 0.0025492468134414832,
#  225235528: 0.0032444959443800694,
#  10671602: 0.023638470451911937,
#  514550692: 0.002085747392815759,
#  156176094: 0.00764774044032445,
#  342943472: 0.009038238702201622,
#  203279955: 0.004171494785631518,
#  198591276: 0.0018539976825028969,
#  19311729: 0.0037079953650057938,
#  24542441: 0.0016222479721900347,
#  382368139: 0.0030127462340672076,
#  27855118: 0.022247972190034764,
#  100174502: 0.0013904982618771727,
#  275081385: 0.0004634994206257242,
#  279390084: 0.0037079953650057938,
#  378862802: 0.0025492468134414832,
#  254054375: 0.0006952491309385864,
#  378546078: 0.0032444959443800694,
#  211235703: 0.0009269988412514484,
#  258568696: 0.0030127462340672076,
#  340329096: 0.0013904982618771727,
#  338517106: 0.004634994206257242,
#  57333800: 0.0027809965237543454,
#  18511475: 0.0013904982618771727,
#  299413847: 0.0016222479721900347,
#  24044209: 0.0011587485515643105,
#  270931952: 0.0011587485515643105,
#  246456451: 0.0011587485515643105,
#  188809568: 0.002085747392815759,
#  290769740: 0.002085747392815759,
#  273504184: 0.0002317497103128621,
#  5490392: 0.005561993047508691,
#  215719802: 0.0011587485515643105,
#  28482819: 0.0018539976825028969,
#  224424715: 0.0006952491309385864,
#  264991283: 0.0006952491309385864,
#  260426661: 0.002317497103128621,
#  76966145: 0.0009269988412514484,
#  7846: 0.0025492468134414832,
#  11487372: 0.0004634994206257242,
#  93904918: 0.0006952491309385864,
#  322603418: 0.0004634994206257242,
#  216299334: 0.0013904982618771727,
#  526921548: 0.0009269988412514484,
#  382111375: 0.0002317497103128621,
#  288452305: 0.0009269988412514484,
#  502167306: 0.0004634994206257242,
#  79004401: 0.0009269988412514484,
#  11926442: 0.0009269988412514484,
#  17006157: 0.0009269988412514484,
#  35831704: 0.00880648899188876,
#  254163476: 0.0002317497103128621,
#  52205516: 0.0002317497103128621,
#  324544865: 0.002317497103128621,
#  338844588: 0.0004634994206257242,
#  363925204: 0.0002317497103128621,
#  116770718: 0.0002317497103128621,
#  48415669: 0.0004634994206257242,
#  58120486: 0.0002317497103128621,
#  126139466: 0.0004634994206257242,
#  47041310: 0.0002317497103128621,
#  309633527: 0.0002317497103128621,
#  16677622: 0.01645422943221321,
#  11214332: 0.0037079953650057938,
#  306128912: 0.005561993047508691,
#  24129206: 0.016917728852838935,
#  334735103: 0.00764774044032445,
#  16009851: 0.017844727694090384,
#  194347664: 0.004866743916570104,
#  39234189: 0.011355735805330244,
#  21507738: 0.009038238702201622,
#  19653925: 0.015990730011587486,
#  19802879: 0.047045191193511006,
#  36584174: 0.00880648899188876,
#  42950930: 0.010196987253765933,
#  19658826: 0.012514484356894553,
#  9852542: 0.008342989571263035,
#  23739721: 0.015063731170336037,
#  42979224: 0.011123986095017382,
#  36045367: 0.011819235225955968,
#  14693823: 0.023174971031286212,
#  14912435: 0.004634994206257242,
#  17248121: 0.0039397450753186555,
#  12321512: 0.01320973348783314,
#  65360193: 0.00440324449594438,
#  92306628: 0.01436848203939745,
#  19766517: 0.022479721900347624,
#  15862891: 0.009733487833140209,
#  21436960: 0.045654692931633836,
#  86070159: 0.023638470451911937,
#  384761809: 0.007184241019698725,
#  69248730: 0.009501738122827346,
#  82853372: 0.011355735805330244,
#  138725262: 0.008574739281575898,
#  25066853: 0.008111239860950173,
#  8295072: 0.013673232908458864,
#  20427778: 0.0030127462340672076,
#  5402612: 0.002317497103128621,
#  15165493: 0.04148319814600232,
#  15102849: 0.04101969872537659,
#  8963722: 0.007879490150637311,
#  106061616: 0.004171494785631518,
#  126302054: 0.0050984936268829665,
#  231796277: 0.0025492468134414832,
#  13176312: 0.04264194669756663,
#  560452336: 0.0039397450753186555,
#  2811851: 0.006257242178447277,
#  15144542: 0.008342989571263035,
#  16876667: 0.016917728852838935,
#  621573: 0.006720741599073001,
#  72841362: 0.004634994206257242,
#  106786180: 0.0009269988412514484,
#  22139698: 0.016222479721900347,
#  91373517: 0.009038238702201622,
#  21410687: 0.00440324449594438,
#  70160230: 0.004866743916570104,
#  17217640: 0.01853997682502897,
#  14936377: 0.019003476245654693,
#  8255122: 0.006257242178447277,
#  24244836: 0.012514484356894553,
#  7429892: 0.029200463499420626,
#  45957677: 0.0011587485515643105,
#  104585489: 0.01320973348783314,
#  93714983: 0.02178447276940904,
#  15234407: 0.01645422943221321,
#  104989762: 0.015758980301274622,
#  17384099: 0.02410196987253766,
#  15431856: 0.009269988412514484,
#  15820660: 0.01320973348783314,
#  18720204: 0.006257242178447277,
#  1435461: 0.014831981460023175,
#  344776030: 0.0074159907300115875,
#  216366465: 0.004866743916570104,
#  158283753: 0.0037079953650057938,
#  266464616: 0.015527230590961762,
#  12040102: 0.005330243337195829,
#  15292446: 0.0027809965237543454,
#  11348282: 0.04101969872537659,
#  90746337: 0.004634994206257242,
#  14091091: 0.020625724217844726,
#  117017147: 0.005561993047508691,
#  244082406: 0.005561993047508691,
#  15473958: 0.038702201622247974,
#  423745970: 0.0018539976825028969,
#  21179815: 0.0039397450753186555,
#  518403776: 0.011123986095017382,
#  256889809: 0.010196987253765933,
#  8623332: 0.006720741599073001,
#  31401966: 0.0037079953650057938,
#  14807898: 0.013441483198146002,
#  14647570: 0.0220162224797219,
#  274663230: 0.005561993047508691,
#  208442526: 0.0074159907300115875,
#  205195655: 0.007879490150637311,
#  474423064: 0.0025492468134414832,
#  6408382: 0.006257242178447277,
#  19816089: 0.0030127462340672076,
#  277375017: 0.004171494785631518,
#  16363491: 0.016917728852838935,
#  51274038: 0.0030127462340672076,
#  42380766: 0.004171494785631518,
#  277889424: 0.002317497103128621,
#  99851285: 0.0018539976825028969,
#  15110431: 0.011123986095017382,
#  4620451: 0.0305909617612978,
#  131663151: 0.0037079953650057938,
#  19384258: 0.008574739281575898,
#  137320881: 0.00764774044032445,
#  403339965: 0.002085747392815759,
#  19725644: 0.039165701042873695,
#  21808052: 0.0027809965237543454,
#  174784400: 0.009038238702201622,
#  523340129: 0.0009269988412514484,
#  222178782: 0.0016222479721900347,
#  277510682: 0.0025492468134414832,
#  71502330: 0.0025492468134414832,
#  437806648: 0.002085747392815759,
#  234343491: 0.0009269988412514484,
#  225096128: 0.0006952491309385864,
#  18700629: 0.0009269988412514484,
#  20950208: 0.00880648899188876,
#  132249368: 0.004171494785631518,
#  16265412: 0.005561993047508691,
#  41494136: 0.0039397450753186555,
#  17176990: 0.0030127462340672076,
#  114115460: 0.011587485515643106,
#  14743923: 0.0039397450753186555,
#  268479669: 0.006025492468134415,
#  2260771: 0.006952491309385863,
#  16264063: 0.004866743916570104,
#  22169313: 0.0025492468134414832,
#  28889701: 0.0025492468134414832,
#  20567578: 0.005793742757821553,
#  14239780: 0.0032444959443800694,
#  15775181: 0.004866743916570104,
#  14456842: 0.006952491309385863,
#  207936757: 0.006257242178447277,
#  7668432: 0.0013904982618771727,
#  61336370: 0.0027809965237543454,
#  3359851: 0.06581691772885284,
#  243370113: 0.0039397450753186555,
#  142001754: 0.0037079953650057938,
#  175624200: 0.011819235225955968,
#  29206754: 0.0009269988412514484,
#  19136295: 0.0025492468134414832,
#  347466350: 0.005793742757821553,
#  7098022: 0.008111239860950173,
#  25071725: 0.0016222479721900347,
#  256286568: 0.0034762456546929316,
#  54319516: 0.0018539976825028969,
#  26553971: 0.0009269988412514484,
#  208221645: 0.0006952491309385864,
#  4219131: 0.005561993047508691,
#  16507381: 0.0011587485515643105,
#  20621747: 0.0025492468134414832,
#  18742444: 0.014831981460023175,
#  263352652: 0.0018539976825028969,
#  189234283: 0.0025492468134414832,
#  49666201: 0.0011587485515643105,
#  34068984: 0.004171494785631518,
#  369130833: 0.0011587485515643105,
#  50393960: 0.01205098493626883,
#  14110133: 0.0009269988412514484,
#  14484504: 0.002317497103128621,
#  117533865: 0.0027809965237543454,
#  350072433: 0.0013904982618771727,
#  34662645: 0.004171494785631518,
#  14192988: 0.0018539976825028969,
#  17738564: 0.0025492468134414832,
#  19663597: 0.0013904982618771727,
#  44177692: 0.002085747392815759,
#  42579112: 0.00440324449594438,
#  63273064: 0.0027809965237543454,
#  76774950: 0.0030127462340672076,
#  245076474: 0.0018539976825028969,
#  236719823: 0.0030127462340672076,
#  17064514: 0.0002317497103128621,
#  20106337: 0.0016222479721900347,
#  40364293: 0.0002317497103128621,
#  248992493: 0.0006952491309385864,
#  17910878: 0.0009269988412514484,
#  14219826: 0.0016222479721900347,
#  283612037: 0.0011587485515643105,
#  166729867: 0.0009269988412514484,
#  41648744: 0.0013904982618771727,
#  24109979: 0.0009269988412514484,
#  59378077: 0.0004634994206257242,
#  823860: 0.0004634994206257242,
#  190752867: 0.0009269988412514484,
#  341849215: 0.0006952491309385864,
#  304794994: 0.0009269988412514484,
#  18208354: 0.0006952491309385864,
#  30034583: 0.0002317497103128621,
#  24563388: 0.0002317497103128621,
#  64209144: 0.0002317497103128621,
#  52422878: 0.0009269988412514484,
#  36803580: 0.0004634994206257242,
#  29758446: 0.0006952491309385864,
#  16565797: 0.0006952491309385864,
#  19490867: 0.0004634994206257242,
#  105429988: 0.0002317497103128621,
#  93750955: 0.0018539976825028969,
#  563031699: 0.0018539976825028969,
#  130340054: 0.0027809965237543454,
#  487367041: 0.0025492468134414832,
#  107381955: 0.002085747392815759,
#  215824411: 0.0016222479721900347,
#  207878118: 0.005561993047508691,
#  390455433: 0.0016222479721900347,
#  85891683: 0.01853997682502897,
#  130357109: 0.0025492468134414832,
#  133929572: 0.002085747392815759,
#  304774444: 0.002317497103128621,
#  18142375: 0.007879490150637311,
#  1294741: 0.009501738122827346,
#  16139649: 0.006488991888760139,
#  17363890: 0.00440324449594438,
#  19344585: 0.0039397450753186555,
#  1002351: 0.006025492468134415,
#  19346439: 0.006257242178447277,
#  14085096: 0.006025492468134415,
#  104203233: 0.006025492468134415,
#  9142362: 0.0030127462340672076,
#  26985345: 0.006720741599073001,
#  33852508: 0.005330243337195829,
#  25702003: 0.004171494785631518,
#  85794542: 0.004634994206257242,
#  56169454: 0.005330243337195829,
#  25995437: 0.0050984936268829665,
#  22021978: 0.0050984936268829665,
#  58836363: 0.004634994206257242,
#  88722311: 0.004171494785631518,
#  9442262: 0.0030127462340672076,
#  87652742: 0.002085747392815759,
#  18874097: 0.005793742757821553,
#  14190551: 0.006257242178447277,
#  41351472: 0.0039397450753186555,
#  465973: 0.006257242178447277,
#  21697211: 0.002085747392815759,
#  149075605: 0.0002317497103128621,
#  16133363: 0.006025492468134415,
#  24185807: 0.0025492468134414832,
#  61228125: 0.0025492468134414832,
#  89479311: 0.0009269988412514484,
#  123567601: 0.0002317497103128621,
#  86337034: 0.0009269988412514484,
#  107017176: 0.004634994206257242,
#  84563846: 0.0032444959443800694,
#  39055030: 0.0016222479721900347,
#  82406734: 0.0013904982618771727,
#  37883682: 0.0011587485515643105,
#  30869029: 0.0006952491309385864,
#  24160143: 0.0009269988412514484,
#  19722805: 0.0002317497103128621,
#  18186507: 0.0004634994206257242,
#  247200654: 0.0002317497103128621,
#  14796276: 0.0009269988412514484,
#  9568572: 0.0004634994206257242,
#  6143852: 0.0002317497103128621,
#  ...}

# %%
degree_centrality = nx.centrality.degree_centrality(G)
#Top 5 nodos con máyor grado de centralidad
(sorted(degree_centrality.items(), key=lambda item: item[1], reverse=True))[:5]
# Out:
# [(48485771, 0.07022016222479723),
#  (5442012, 0.06813441483198146),
#  (3359851, 0.06581691772885284),
#  (40981798, 0.06257242178447277),
#  (43003845, 0.0593279258400927)]

# %% [markdown]
# Los siguientes son los principales nodos que generan agrupaciones o tienen mayor influencia en la red.

# %%
#Visualizar los vecinos de dichos nodos
(sorted(G.degree, key=lambda item: item[1], reverse=True))[:5]
# Out:
# [(48485771, 303),
#  (5442012, 294),
#  (3359851, 284),
#  (40981798, 270),
#  (43003845, 256)]

# %%
# Visulizar histograma de grados de centralidad
plt.figure(figsize=(15, 8))
plt.hist(degree_centrality.values(), bins=10)
plt.xticks(ticks=[0, 0.0125, 0.025, 0.0375, 0.05, 0.0625, 0.075])  # set the x axis ticks
plt.title("Histograma grados de centralidad ", fontdict={"size": 20}, loc="center")
plt.xlabel("Grados de Centralidad", fontdict={"size": 12})
plt.ylabel("Conteo", fontdict={"size": 12})
# Out:
# Text(0, 0.5, 'Conteo')

# %% [markdown]
# La mayor cantidad de nodos tienen un valor de centralidad menor a 0.0375. Efectivamente observamos que la mayoría de nodos no tienen una influencia alta sobre la red o sobre su capacidad de generar interacciones entre sí.

# %%
# Visualizar los nodos con mayor grado de centralidad
node_size = [v * 1000 for v in degree_centrality.values()]
plt.figure(figsize=(15, 8))
nx.draw_networkx(G, pos=pos, node_size=node_size, with_labels=False, width=0.10)
plt.axis("off")
# Out:
# (np.float64(-0.6459476724267006),
#  np.float64(1.1564022675156593),
#  np.float64(-1.0558947339653968),
#  np.float64(0.7013561144471169))

# %% [markdown]
# ###Centralidad de intermediación

# %%
nx.centrality.betweenness_centrality(G)
# Out:
# {214328887: 2.5082908314481238e-05,
#  34428380: 0.021037197466361186,
#  17116707: 6.971806170023784e-05,
#  28465635: 0.0006583211358037852,
#  380580781: 1.535309473005652e-06,
#  18996905: 8.086118806320171e-05,
#  221036078: 1.3483838335327062e-06,
#  153460275: 4.180837210387545e-07,
#  107830991: 4.688563902873442e-06,
#  17868918: 5.98601870685985e-05,
#  151338729: 6.077229298716775e-05,
#  222261763: 5.605161318787643e-06,
#  19705747: 0.0001280696304836396,
#  88323281: 0.00011958831911943022,
#  19933035: 2.2008440975508994e-05,
#  149538028: 7.212386235859093e-06,
#  158419434: 0.00014728504020676338,
#  17434613: 0.00014750298457727842,
#  153226312: 6.708732148285042e-05,
#  364971269: 5.862132071628127e-06,
#  100581193: 4.896410274620717e-05,
#  279787626: 0.0007676081596227947,
#  113058991: 7.134156181906071e-06,
#  69592091: 2.2158881804864713e-05,
#  187773078: 0.002265761724977153,
#  406628822: 3.2803518743971713e-06,
#  262802533: 6.532614317196061e-07,
#  460282402: 5.091651663248e-07,
#  280935165: 4.964699005072598e-06,
#  437804658: 1.8676081149986261e-07,
#  27633075: 3.9391348750544905e-05,
#  285312927: 8.99854200827709e-07,
#  131613362: 5.247049626402476e-06,
#  17675120: 5.417538060713578e-06,
#  394263193: 0.0002532491423892023,
#  254839786: 3.993437483268046e-05,
#  204317520: 2.6598318307183825e-05,
#  21548772: 1.0910874698634054e-06,
#  67864340: 6.848096729027225e-06,
#  172883064: 0.00014816268776613755,
#  270449528: 2.5707334816741863e-05,
#  297801196: 7.14384435831257e-07,
#  8088112: 2.9580320970948264e-05,
#  14925700: 3.9137995155807975e-06,
#  124528830: 3.7372853293237362e-06,
#  307458983: 4.426491025802692e-05,
#  160237722: 1.8844634405285484e-06,
#  220368467: 8.77891699449974e-05,
#  54228724: 0.00025517973133971895,
#  206923844: 3.670830907491849e-05,
#  103598216: 4.4563343253036985e-06,
#  207594668: 2.0696823517161904e-06,
#  21146135: 0.004921730690414418,
#  451250774: 2.4312756764964682e-05,
#  314316607: 1.8689536573462484e-05,
#  6581292: 2.48604324633328e-06,
#  31331740: 6.93831964016881e-05,
#  196327549: 6.229231020058214e-06,
#  225444667: 2.0677383877620486e-05,
#  274153775: 4.034904174235243e-05,
#  35415466: 5.477680516434775e-06,
#  72818790: 5.596275166711632e-06,
#  324201646: 8.416645381546315e-09,
#  40981798: 0.029029047678193795,
#  430268163: 3.4341976291429943e-06,
#  88097807: 0.008247003082573767,
#  276308596: 2.5430518987212224e-05,
#  358775055: 4.765787375233999e-05,
#  15023872: 1.0470877926028999e-05,
#  16870853: 2.2389877964068433e-06,
#  70492333: 0.026809077507013106,
#  430313102: 6.260113954090645e-07,
#  299715516: 0.0007687471726440609,
#  35359596: 1.920975735097158e-06,
#  276577539: 2.3561147432730847e-06,
#  248883350: 3.030903169577633e-06,
#  157829215: 0.00028326994757490754,
#  107511013: 1.8184444582419482e-08,
#  22462180: 0.020783634179006465,
#  258140947: 0.002195842678928116,
#  200559228: 0.0012441245453206592,
#  19493072: 4.418430964336287e-05,
#  123371682: 0.00022737671208584978,
#  461410856: 0.0003486973919629215,
#  31414569: 0.0021426797647027982,
#  37699718: 1.627405836337416e-06,
#  117901353: 6.033019674227829e-06,
#  117674417: 2.991296454276265e-05,
#  231238695: 1.3002889528509986e-06,
#  56860418: 8.047664059754826e-06,
#  43003845: 0.027714099503968276,
#  413275344: 7.208266341506657e-07,
#  259842341: 3.628750996945434e-05,
#  400689940: 1.660648552530516e-06,
#  26929220: 7.563014944877953e-05,
#  35148062: 3.8285537124142605e-05,
#  166214735: 4.710764016905804e-05,
#  57490887: 4.80606456249694e-05,
#  148519842: 0.00016196711606579958,
#  15150609: 0.0005350920427786961,
#  17759158: 2.780486542821634e-06,
#  83943787: 3.540652425725869e-05,
#  283306479: 0.0021309524545565445,
#  125120339: 5.800368648991503e-05,
#  220068522: 0.0006626967715454218,
#  155661154: 5.186601282055382e-05,
#  195475105: 7.851320733935863e-05,
#  134940306: 7.174595247456546e-05,
#  115221382: 3.356396138462138e-05,
#  368018677: 1.0307326713891264e-07,
#  439788025: 2.290908583745056e-05,
#  262340283: 0.0017565562708687042,
#  116498875: 0.002667300709347716,
#  257236842: 6.717458971618255e-05,
#  128721580: 2.0238577559732356e-07,
#  463952369: 5.1765852270774126e-05,
#  254610699: 9.245102829466104e-07,
#  247741328: 2.1510235591276785e-05,
#  226629405: 0.0001214922419302084,
#  529007327: 1.2383429857849631e-05,
#  94621855: 4.620800281715152e-07,
#  83417972: 0.004364752603969764,
#  236184723: 5.7139261298057515e-05,
#  197504076: 0.00032793286074640874,
#  86221475: 4.019666002518724e-06,
#  222411742: 2.3302935658666318e-07,
#  250178329: 3.8477253529156336e-07,
#  292598082: 8.01615966452831e-07,
#  145845459: 1.3979097679727248e-06,
#  29911100: 3.910920521939244e-06,
#  294752666: 0.00028750183567939294,
#  27077521: 1.2874005510725059e-05,
#  163238842: 9.710030548178228e-07,
#  133055665: 1.5896890451132315e-05,
#  238201669: 0.00025260952837635666,
#  260769396: 5.059473071084016e-07,
#  288485704: 1.1885781810264438e-05,
#  229425177: 2.045493185799408e-05,
#  252770012: 5.97533705466825e-07,
#  121533789: 1.0088420005534484e-05,
#  203338499: 0.00043901835842666536,
#  213777144: 0.004368135734022689,
#  46209291: 0.005796302102629468,
#  46831674: 7.708426425757261e-05,
#  18951737: 1.0322038743471523e-06,
#  239144776: 1.8684023080204387e-05,
#  8163442: 0.0005233061278104895,
#  28019653: 3.458135254228072e-07,
#  447688115: 1.2697346718686191e-06,
#  16503181: 1.4991911258385225e-05,
#  109740608: 2.7440341332277772e-05,
#  116036694: 5.885440741992156e-05,
#  179138862: 4.631482505640894e-07,
#  276706356: 0.0005708949355763185,
#  236143101: 5.422452921033725e-05,
#  333161611: 4.941630521154252e-07,
#  19358562: 6.7718280646640995e-06,
#  226165839: 1.4984385929656765e-05,
#  33612973: 0.00014625421035393386,
#  37270037: 0.00011979186153178929,
#  49104918: 0.0008507279811679853,
#  83032174: 1.4602214860715235e-05,
#  55033682: 1.7670945681906317e-05,
#  170460311: 5.515830617811443e-07,
#  152388029: 0.00023667518686371408,
#  112939321: 2.1567698903130314e-05,
#  265077741: 1.4860691376898521e-05,
#  261447035: 9.915015245365356e-08,
#  120599128: 0.0009785887088997391,
#  186212304: 0.0019694952198160355,
#  57828817: 6.879360358178745e-06,
#  250340951: 4.881820057351839e-07,
#  59588845: 3.754467954823573e-05,
#  2367911: 0.0007595296417729834,
#  74107696: 1.8411991425116273e-05,
#  477094958: 1.7563262867838588e-06,
#  233248636: 1.6737546997753305e-05,
#  86799233: 3.3418976073077474e-07,
#  17627996: 3.0538844828717317e-07,
#  30971165: 9.763774842861078e-05,
#  271602109: 0.00014257745842725833,
#  81446304: 6.378061695684049e-08,
#  282206645: 9.280546094312115e-08,
#  31317273: 3.9366371024212045e-07,
#  204140367: 7.826778383205916e-06,
#  189875309: 2.255774178399351e-05,
#  170167167: 7.19005071989787e-05,
#  45333725: 1.4966449335372431e-05,
#  222090651: 2.98351055386987e-06,
#  93224416: 1.097480046711065e-06,
#  355823615: 5.101987169693141e-05,
#  309782398: 1.471489925885544e-05,
#  253091523: 1.163816072572837e-05,
#  349413327: 3.567876549508637e-05,
#  375317198: 1.6534218809640506e-06,
#  31246395: 1.1469970346907231e-07,
#  200884513: 3.075601015635436e-08,
#  312284236: 4.279496134013476e-07,
#  260705759: 1.7899028587346545e-06,
#  43640117: 5.092169863089231e-07,
#  236026868: 1.2098808127145849e-06,
#  95260836: 0.000177659082787048,
#  63941463: 5.23497665963021e-09,
#  83155222: 4.637477243313089e-05,
#  451493376: 0.0,
#  73738774: 0.00019912312241468762,
#  100052945: 5.092424071661132e-07,
#  21272026: 1.828948208149973e-05,
#  33806113: 1.3415714906863374e-06,
#  9695312: 0.00013229993409963735,
#  272173354: 4.713462597243759e-06,
#  41472982: 1.2764465256500232e-05,
#  287915525: 0.00013458260822694963,
#  105259389: 1.387824588200849e-07,
#  31457243: 5.673485607456846e-05,
#  102765423: 4.551281358129665e-06,
#  273149543: 1.7272040159524626e-07,
#  53222305: 7.845472702367643e-06,
#  215787132: 0.0004310145701838326,
#  375228586: 6.320044460248769e-09,
#  72680406: 6.49314046198896e-06,
#  11259362: 1.831047941070507e-05,
#  16216637: 1.7946637340472428e-05,
#  767809: 7.70976993423805e-08,
#  30690708: 7.223617255114371e-07,
#  5992502: 1.0635239934871281e-05,
#  17859804: 3.6821159037672946e-06,
#  83876527: 4.039470614880872e-05,
#  19681661: 9.731182057939232e-06,
#  15465769: 4.698836204307724e-07,
#  22689667: 3.3182031693329502e-06,
#  195409031: 1.211419502102566e-06,
#  57261575: 2.0689044460378887e-06,
#  4126501: 9.379273712364332e-06,
#  22558481: 3.243791777034888e-07,
#  18109441: 7.859007578431855e-06,
#  60607157: 2.715506732036042e-07,
#  25615305: 2.1819895087096014e-05,
#  16877939: 1.2973153702151478e-06,
#  21734241: 2.351511736730449e-06,
#  46073276: 3.082101665978191e-05,
#  166002579: 1.1140170534770296e-08,
#  6463042: 1.1491087349872856e-05,
#  96770886: 1.9068511926714901e-06,
#  7712232: 1.34571291714868e-07,
#  99211591: 7.4698379997906175e-06,
#  23930272: 1.6704637278428759e-06,
#  37977732: 1.368796139651431e-05,
#  16858804: 1.3590151059650132e-07,
#  44436825: 1.2770913836075401e-05,
#  28359405: 3.43654006343371e-06,
#  9973842: 2.7043242441576165e-05,
#  451331227: 8.121742863186288e-07,
#  55113: 3.2070451759969095e-06,
#  124746917: 1.0879344008589603e-05,
#  41048052: 2.9470357241396185e-06,
#  14677919: 5.075904543145718e-05,
#  203827751: 1.5571676855917428e-05,
#  10075442: 4.206452677292488e-06,
#  17342842: 1.7230694732820866e-05,
#  17477343: 3.838762398121494e-06,
#  56318573: 3.825224173870255e-06,
#  111615736: 4.476896960843415e-06,
#  83529586: 1.5037722964066545e-07,
#  9503302: 6.849884429482877e-07,
#  5533902: 5.005348823068412e-07,
#  14551276: 9.649464639529465e-06,
#  17870886: 1.4094635017842139e-05,
#  98976495: 1.8275313890804697e-06,
#  22200888: 1.0180902581063424e-05,
#  88974843: 1.4044213608969332e-06,
#  16967011: 3.4066824047450374e-07,
#  171145913: 1.2285989568555544e-05,
#  163937752: 2.4737643956880534e-06,
#  21742517: 3.019792324277505e-06,
#  113415132: 4.351959406963808e-07,
#  79797834: 3.6497049479584885e-05,
#  18758940: 2.6236521338799214e-06,
#  138549366: 4.152932332283664e-06,
#  19230869: 1.0253183185232697e-07,
#  84111527: 2.8546553667826527e-07,
#  50944856: 2.1603630745082462e-06,
#  117998529: 3.104490470297895e-05,
#  23150071: 3.6064033950917057e-06,
#  14169740: 1.0816590277047511e-05,
#  38718720: 1.3126752050876815e-05,
#  93906304: 2.707386241192508e-06,
#  6127252: 7.749481407734016e-07,
#  20757640: 7.761719021531793e-07,
#  17902348: 3.1633853118639933e-06,
#  59557446: 1.090901545667017e-06,
#  27703441: 4.377779163392539e-07,
#  23484510: 2.9123511019141494e-07,
#  792998: 7.18986861028115e-07,
#  18344173: 3.388694795512918e-07,
#  20583098: 8.753807390906801e-06,
#  55019225: 1.6118945783392187e-07,
#  2705: 4.9205465378593584e-06,
#  557196973: 1.5348679403461295e-08,
#  23483324: 3.4332133380665987e-06,
#  21074641: 1.3027911975688373e-05,
#  52073562: 0.0,
#  30486243: 2.9117946544418858e-06,
#  174118650: 5.2721692164260634e-08,
#  25835874: 1.0184421887098713e-05,
#  17293897: 3.48766800526685e-06,
#  349256925: 1.2243960777689923e-08,
#  258681133: 0.0,
#  454423088: 0.0,
#  22879382: 0.0,
#  155613846: 4.1830718239433565e-07,
#  35476618: 0.0,
#  137355085: 0.0,
#  30204310: 1.64891715535796e-08,
#  291476217: 0.0,
#  236575672: 9.99053613458908e-07,
#  82030021: 0.0029460786027487697,
#  17037417: 0.0,
#  28149277: 5.617847209273422e-06,
#  111164068: 0.0001209231288323338,
#  29514951: 0.001967798742825189,
#  94918917: 0.0,
#  131601987: 0.0013693889888238408,
#  159629146: 0.00010330274704254297,
#  90722891: 0.0001813162827413925,
#  90779436: 0.00017233258173318168,
#  22784458: 0.005822463063855039,
#  191620115: 1.5322472481988108e-05,
#  15999863: 6.725052226001405e-05,
#  146556805: 1.0798620745141427e-06,
#  118811608: 0.00010082251175939042,
#  95980722: 5.40004271983986e-06,
#  104155395: 4.1452648553427265e-06,
#  51477206: 5.594579076710397e-07,
#  101903164: 1.7816968832098093e-07,
#  14683518: 0.0008409509345946694,
#  34805698: 0.0,
#  176872879: 5.98075144440021e-05,
#  28144741: 0.00044493903005708864,
#  37876253: 0.0,
#  293353298: 0.00021282402685621275,
#  239257866: 0.0,
#  14876672: 0.0005792538282211621,
#  486930916: 0.0,
#  101859065: 0.004479673229604395,
#  263907906: 0.0,
#  23152989: 3.777853590082572e-05,
#  345707398: 0.0,
#  203623462: 9.890368371532848e-05,
#  61065794: 0.00028508207605786615,
#  301695120: 0.0002630504266743791,
#  102364313: 0.0007406319632550628,
#  211670208: 1.194902044812065e-05,
#  37008705: 0.0010608104655058976,
#  112819301: 5.146937345463522e-06,
#  352035443: 2.5844936202397617e-07,
#  250849104: 2.5610911224644503e-06,
#  19153742: 7.133427928845679e-06,
#  161788974: 7.111579957453078e-07,
#  147946019: 0.0002884029455886066,
#  54581743: 0.004956495133990268,
#  235163686: 2.1184071179270416e-07,
#  22440364: 0.0009752140427561492,
#  54611487: 0.007420858475554508,
#  34507480: 0.0006995425117462727,
#  243836182: 6.367339799262859e-07,
#  164422299: 5.311725862937201e-06,
#  27772095: 0.0005932502721465964,
#  22592948: 0.0006576208760196449,
#  328158079: 0.00027295816003208894,
#  143838260: 0.000513295021171464,
#  58309829: 9.222027725700337e-06,
#  135268094: 0.002239861083059162,
#  222802532: 1.8919284014897822e-05,
#  23375688: 0.0011650445219177474,
#  25970331: 0.003416111188224365,
#  19383317: 0.00022107951967596928,
#  230505689: 2.5781658431430656e-08,
#  100318079: 0.0036255277214945754,
#  206416476: 4.357500257366017e-06,
#  15460081: 0.0018680668712305602,
#  20271494: 2.1571463364648966e-06,
#  169504184: 0.00042080228816924304,
#  16824090: 1.4125011362931601e-06,
#  115525090: 1.9462014607903464e-06,
#  29654458: 0.00014977260966621912,
#  26649453: 0.00014135547371510885,
#  14425825: 0.0006607906947667999,
#  421412483: 0.0003864322449315375,
#  243227325: 1.9688404872865433e-06,
#  240944206: 5.26672882927695e-07,
#  63808966: 0.0007860083482535378,
#  16895295: 0.00011037343441162655,
#  243273954: 1.8649374785344938e-06,
#  226516599: 5.722655679063971e-06,
#  163274846: 0.0002601431527310005,
#  111990504: 1.2782410215755884e-05,
#  408060505: 3.4278883947633283e-07,
#  309765553: 0.0002545630572799845,
#  27090278: 1.9005112739635673e-06,
#  225488317: 2.0136154239945746e-07,
#  148081553: 0.0007000505563955625,
#  197090502: 0.00013042304681787727,
#  69373005: 4.998569986717261e-07,
#  48504743: 3.6158208172976634e-07,
#  302936475: 1.4077732422865435e-07,
#  480595611: 5.062701791713995e-07,
#  40968863: 0.009145751714245165,
#  34270956: 8.793463048893123e-05,
#  2883841: 0.0003057496651454899,
#  325054079: 6.08116335042535e-08,
#  126470482: 0.0,
#  181288376: 0.0002317210231731897,
#  250988604: 0.0004449121698681326,
#  171704225: 2.0249812898989859e-07,
#  158526208: 2.009318473419334e-05,
#  192023970: 3.5548579195584306e-06,
#  339373057: 3.375484721392796e-05,
#  193593048: 0.0033075602637246066,
#  176222605: 0.0,
#  244719623: 4.132336762470349e-09,
#  335678635: 0.0,
#  79817691: 4.952827891681583e-08,
#  109698612: 3.609228866007459e-07,
#  208105146: 3.0615218142673604e-07,
#  25592034: 1.7775607343324834e-08,
#  333011515: 0.00045034839545793766,
#  258490941: 1.5245622045482185e-05,
#  342221618: 0.0,
#  32032000: 0.0002763377586987698,
#  19507713: 0.0005123665322797679,
#  16583672: 6.864929927538056e-05,
#  35918787: 0.00013593618129867745,
#  20803125: 2.1599528148356966e-05,
#  311776211: 1.8504733185625128e-06,
#  16079941: 0.00013438093412006935,
#  7861312: 0.031431525694284354,
#  7860742: 0.049990437905017386,
#  9955652: 8.046019819917507e-06,
#  462541005: 2.1705241425512604e-05,
#  20747741: 0.0002353259736006824,
#  17047105: 0.00048593561399724004,
#  23559552: 1.543245821914844e-05,
#  20106852: 9.573044031674444e-05,
#  51246108: 3.197480754461496e-05,
#  20637608: 0.00034163157724828976,
#  434725454: 1.1387527136782685e-05,
#  18927441: 0.009524627746314735,
#  18666844: 0.00336169854829068,
#  15666380: 0.07953763787324364,
#  365014160: 4.3727425897877846e-06,
#  21158690: 0.0008038382213605622,
#  15271920: 0.00015818135104138758,
#  16786977: 0.0005819281592506466,
#  373018050: 0.00030785660311640297,
#  369586333: 1.0064558012037997e-05,
#  96747353: 0.0007054404265302484,
#  16799897: 0.00023323660102784547,
#  51162310: 0.00020828947559594052,
#  18130749: 3.7922560564157064e-05,
#  317846921: 0.00019683039486319902,
#  130897520: 0.00022618956691200764,
#  363426409: 0.0002936516935076207,
#  438460947: 1.8384766076495538e-06,
#  58714972: 0.0004537390603057123,
#  16663695: 0.0001327610527634813,
#  47799910: 4.1061695728707974e-05,
#  31808762: 0.0011997196258978036,
#  14888584: 0.00034170753583903277,
#  315338495: 4.345640674572962e-05,
#  352226153: 0.0005173132218471296,
#  300599613: 3.1062103803677105e-06,
#  16909832: 0.00010853713153383097,
#  167744987: 1.416887256150341e-05,
#  362286999: 6.383115723342388e-05,
#  126099878: 0.00041528193730251765,
#  422066630: 3.8632952821257585e-06,
#  191638793: 0.0003819342068675481,
#  16038438: 0.004582589811521148,
#  390811153: 9.848503705535892e-07,
#  794186: 0.00014276471041982386,
#  394216985: 4.156293078409428e-05,
#  17105214: 0.0005213774395051341,
#  126042901: 0.00021899293085796603,
#  7384432: 0.00017361123530010636,
#  95820486: 1.1574662031490314e-05,
#  62050341: 0.00014797757187571983,
#  15343773: 0.0002665119471479564,
#  19049747: 0.0025872589175277793,
#  167010482: 0.00017824352358998788,
#  60101131: 7.931520770580565e-06,
#  299715714: 5.390873744969949e-05,
#  7079062: 4.724997680153341e-05,
#  88501703: 0.00045992168883833237,
#  18069427: 4.3270572028783435e-05,
#  405323682: 0.00011432343238697953,
#  404376053: 1.3809217020917761e-05,
#  193059216: 2.917714845721653e-06,
#  20747847: 0.0053023199684591685,
#  7377812: 0.002626606184406172,
#  172959279: 0.0005059190124488833,
#  15439395: 0.021832664147635125,
#  14824849: 0.00543343450741498,
#  110481357: 4.3275214818937756e-06,
#  212018296: 3.203919436375325e-05,
#  15661871: 0.00021826349834178446,
#  17092862: 7.71297677870802e-05,
#  224809136: 0.0005903541792132115,
#  223247584: 0.00011117028656814597,
#  14111650: 0.00016642664549855652,
#  14589257: 0.003113686161051999,
#  310087940: 6.96844641797113e-05,
#  18501326: 0.00011411727218103488,
#  243058696: 1.9392708100096597e-05,
#  18781900: 4.409686255372792e-05,
#  306472866: 0.0003499999232785158,
#  344334227: 4.5847646134329367e-05,
#  7453822: 0.00019492932519530625,
#  357268791: 1.5761210175556934e-05,
#  8207762: 0.0001164617592324019,
#  308324295: 8.132340162930182e-05,
#  16894839: 0.0019267363767637052,
#  280725732: 0.0002905204928275013,
#  26841335: 4.405886122847439e-05,
#  16218063: 3.707047962460191e-05,
#  467658266: 5.178100156040771e-05,
#  8715652: 1.0033836749117847e-07,
#  116511302: 0.00011242042725925624,
#  33087222: 1.4759380544774324e-05,
#  40791597: 0.0,
#  17158189: 0.00016055700858485136,
#  18445879: 0.00010012756288673683,
#  19415126: 2.1334157259582248e-05,
#  25495625: 1.7476489206631642e-05,
#  4893411: 0.00012871799552317,
#  7081402: 0.013507755992660839,
#  143244854: 0.00024690435425700973,
#  23691649: 1.2784487920149805e-06,
#  337131276: 1.6187697316648986e-05,
#  127569781: 0.0006437618190698397,
#  20661527: 0.0026349361308496484,
#  14464369: 0.0005063824931404214,
#  14424667: 0.0005496778567775295,
#  15643370: 0.00020283783827145402,
#  22643137: 4.796274093622199e-06,
#  46241448: 0.00025618604079493296,
#  22857385: 0.000307398803338935,
#  16150457: 2.8997006376714874e-05,
#  15913: 0.028500273680575564,
#  28521141: 0.00012391609617211155,
#  18602163: 1.753411491696439e-05,
#  43662236: 0.0005761004534280413,
#  40340464: 0.0005026897491207977,
#  351671009: 0.0003604152258719009,
#  10350: 0.008600602151896994,
#  24591819: 0.00030600838984498217,
#  59877557: 8.458561141229932e-05,
#  179278975: 0.00011224470608910589,
#  15029953: 5.749443695622452e-07,
#  114563370: 0.00020265268075091682,
#  15575251: 0.004604075732031293,
#  123678437: 6.62811304777526e-05,
#  18849313: 2.8273075088417324e-05,
#  16908436: 0.0002077359146318858,
#  18488495: 8.260544594537233e-05,
#  18125335: 0.0011323348498168395,
#  9199472: 0.0005358101537286661,
#  14311802: 0.00022741500764928812,
#  756379: 0.00018975508971271529,
#  14412605: 5.553848144502808e-05,
#  520027894: 2.586732423951578e-07,
#  15665127: 3.8775412491295326e-05,
#  1183041: 0.012005407005594403,
#  15758036: 0.00014051699830603783,
#  19521118: 6.761385235465889e-06,
#  18444530: 9.378242806117074e-05,
#  87759396: 8.095629757882341e-05,
#  28202547: 0.0005457258588017664,
#  14165096: 0.00025141469714486895,
#  1065921: 0.0013412611659623084,
#  20273398: 0.009834176491358732,
#  16626187: 0.0004293289907974361,
#  19489341: 0.0005488010814098614,
#  6572452: 4.238276330860794e-05,
#  43219574: 8.996049540781432e-07,
#  294430454: 0.0001967481879709708,
#  6068612: 8.042023360984821e-05,
#  14326003: 2.972531458355104e-05,
#  31067157: 0.0007825039573175051,
#  769584: 3.639186708414777e-06,
#  33035636: 3.24013483995401e-06,
#  121637129: 2.8252259967227815e-05,
#  34455805: 1.8067001446807638e-05,
#  468094034: 3.126129509044249e-06,
#  23831909: 3.182398192393003e-05,
#  14303746: 0.00035588205587164376,
#  21076522: 0.000551075011666835,
#  16956955: 5.94924076285497e-05,
#  358553967: 0.00022806991466107126,
#  274149738: 1.643226833528633e-05,
#  50557241: 6.217339394317038e-05,
#  333709376: 0.00023611083315535418,
#  66561957: 0.00011666339147485373,
#  16098603: 0.006302403449256244,
#  48370736: 0.0003357858626788041,
#  187366802: 3.2032379465045685e-06,
#  34170312: 6.63771208919223e-05,
#  283306509: 5.950725812907676e-05,
#  5980142: 0.00020651948148729603,
#  15863699: 0.00011735664675440843,
#  17759701: 0.0035270813470722837,
#  14050306: 2.5829207488228066e-07,
#  23742474: 0.0004696991367637361,
#  16536215: 0.0003556007626208468,
#  18819743: 1.2131448927444174e-05,
#  395395198: 4.535770219109547e-06,
#  20015787: 4.878814151931956e-06,
#  681813: 0.0005542777278583804,
#  56768257: 3.2595853305647223e-07,
#  15359658: 7.324933869629281e-06,
#  41262929: 1.0842507883290952e-07,
#  520809979: 1.969740207841716e-06,
#  18959811: 1.3430094478028634e-08,
#  55656369: 4.652784846744279e-05,
#  125540746: 0.0,
#  3462421: 3.968543677393401e-05,
#  43275782: 0.0,
#  18709570: 2.624884381761474e-05,
#  16583999: 4.416320394353705e-05,
#  167552021: 2.974092618591275e-06,
#  22924257: 7.384566278832246e-05,
#  31892440: 0.0,
#  75193883: 1.07166936735532e-05,
#  14326533: 0.00011063600098875806,
#  23390284: 1.6916873467233928e-05,
#  17865810: 0.0,
#  332375645: 2.510058536952973e-06,
#  7385102: 7.026844374417112e-08,
#  43115008: 2.0812321004841554e-05,
#  254792310: 6.45556270001886e-07,
#  89728799: 2.6205062396153435e-09,
#  14144060: 1.7036712653828482e-07,
#  101496725: 7.501417875947726e-06,
#  405056781: 6.964166221159337e-06,
#  21308602: 3.320753628218165e-05,
#  17794560: 6.76368514855114e-08,
#  54298095: 8.264673524940698e-09,
#  17983020: 0.0,
#  74229529: 2.1045254006056403e-07,
#  26547954: 1.0074179839547416e-06,
#  194889318: 1.884811184551176e-06,
#  118599144: 2.433253774950365e-06,
#  120867457: 0.0,
#  102434415: 0.0001453421571070273,
#  16891273: 0.0,
#  350939079: 5.6882543013510894e-05,
#  323405569: 5.6360465239115356e-05,
#  109065990: 0.0009981233676548222,
#  106708586: 0.00019016643979825136,
#  316797838: 4.821811336737073e-05,
#  374949999: 0.000696680650946333,
#  52216611: 0.00048556864936627594,
#  50453498: 1.8714738736048964e-05,
#  20471349: 0.006341829496510155,
#  497434530: 0.0018347240983591273,
#  18825961: 0.0033997032160318547,
#  308522948: 0.0008787980334651497,
#  17861062: 9.653850361364204e-05,
#  423662810: 5.4026294089704386e-06,
#  433691110: 0.000315358821432192,
#  28125177: 0.00020608990246805318,
#  16589206: 0.00013111087857146806,
#  64643056: 1.6684205202605957e-05,
#  16151999: 0.0,
#  15838599: 1.0992858821672885e-05,
#  515602819: 2.1801100895836872e-05,
#  43611927: 9.576640716936033e-05,
#  55949049: 0.0001432582197443803,
#  294198566: 0.002090968215888662,
#  290656947: 0.0007397978678826063,
#  324546502: 0.0003298786946371188,
#  285727668: 0.0004610573817564758,
#  225235528: 0.0018789870149208353,
#  10671602: 0.04122254836051921,
#  514550692: 0.000354218216710658,
#  156176094: 0.0017399027368765977,
#  342943472: 0.006082751885522808,
#  203279955: 0.0015105294197938393,
#  198591276: 0.00019692869577053523,
#  19311729: 0.0020459373261202266,
#  24542441: 1.7987646756734532e-05,
#  382368139: 0.0003341256861349436,
#  27855118: 0.009704074133134328,
#  100174502: 5.211175465294848e-07,
#  275081385: 1.8059318448223848e-07,
#  279390084: 0.0018997771105792437,
#  378862802: 4.929196491093616e-05,
#  254054375: 5.264333221351443e-07,
#  378546078: 0.0007264668722888826,
#  211235703: 8.141592494443941e-07,
#  258568696: 0.00042174067082409504,
#  340329096: 2.9403565388570457e-05,
#  338517106: 0.00014686024257607613,
#  57333800: 1.2862337025495062e-05,
#  18511475: 0.00048239400341719993,
#  299413847: 0.0010354433132849466,
#  24044209: 0.0007157483385577366,
#  270931952: 2.00726050150753e-05,
#  246456451: 0.0005802127797438629,
#  188809568: 0.0018206172573654584,
#  290769740: 0.00042475653113939265,
#  273504184: 0.0,
#  5490392: 0.003417954948328889,
#  215719802: 4.014102343895176e-07,
#  28482819: 0.0005571024232257222,
#  224424715: 0.0,
#  264991283: 1.926443371415715e-05,
#  260426661: 1.3276424320259787e-05,
#  76966145: 3.797053984242641e-08,
#  7846: 0.000573922425794172,
#  11487372: 0.0,
#  93904918: 0.000197582939117517,
#  322603418: 0.0,
#  216299334: 0.0009659516640596064,
#  526921548: 6.935188825658635e-06,
#  382111375: 0.0,
#  288452305: 0.00047136831799530083,
#  502167306: 0.0,
#  79004401: 1.3433659368670274e-06,
#  11926442: 3.9930399508141574e-05,
#  17006157: 6.467273889522147e-06,
#  35831704: 0.003482034016207862,
#  254163476: 0.0,
#  52205516: 0.0,
#  324544865: 3.7390433109693176e-05,
#  338844588: 0.0,
#  363925204: 0.0,
#  116770718: 0.0,
#  48415669: 0.0,
#  58120486: 0.0,
#  126139466: 0.0,
#  47041310: 0.0,
#  309633527: 0.0,
#  16677622: 0.00044913901295998447,
#  11214332: 5.3995464563563095e-05,
#  306128912: 1.8146557522675366e-06,
#  24129206: 0.000650512342503468,
#  334735103: 1.7218954980892544e-06,
#  16009851: 0.0009881688626622656,
#  194347664: 0.0001053298055865262,
#  39234189: 0.00037261345078989255,
#  21507738: 0.00021790158003456161,
#  19653925: 0.0006004651652067989,
#  19802879: 0.012186751628655733,
#  36584174: 0.0003257097245704514,
#  42950930: 0.00022167933563669995,
#  19658826: 0.000564865702888753,
#  9852542: 0.00022666892242239814,
#  23739721: 0.0006444831887123971,
#  42979224: 0.0002466325518951758,
#  36045367: 0.0004256434855677833,
#  14693823: 0.0002197825440152891,
#  14912435: 9.476516059842591e-07,
#  17248121: 8.47956570992621e-06,
#  12321512: 0.0004662698306605975,
#  65360193: 1.910154330373784e-07,
#  92306628: 0.0003164101442554565,
#  19766517: 0.0014506670461012943,
#  15862891: 0.00025302962631231174,
#  21436960: 0.003031971505667752,
#  86070159: 0.0013542428222264498,
#  384761809: 5.658605555403324e-06,
#  69248730: 0.0001469245015675209,
#  82853372: 0.0003769435910589534,
#  138725262: 0.00015208035007157613,
#  25066853: 0.00010306709075578091,
#  8295072: 0.002461294146210037,
#  20427778: 1.63149380271996e-05,
#  5402612: 3.703141512345073e-07,
#  15165493: 0.00900551029531809,
#  15102849: 0.004097868031041451,
#  8963722: 1.3916839413388943e-05,
#  106061616: 6.145349386643433e-05,
#  126302054: 2.4687599232457175e-05,
#  231796277: 1.5885482489940655e-07,
#  13176312: 0.0009870780671663519,
#  560452336: 5.266835472035175e-05,
#  2811851: 6.449763367393684e-05,
#  15144542: 0.00012082892519843474,
#  16876667: 0.0004922223786702571,
#  621573: 1.3858508437930303e-05,
#  72841362: 3.8232668174083846e-07,
#  106786180: 7.674339701730648e-09,
#  22139698: 0.00012004620196500065,
#  91373517: 0.00023413202385838913,
#  21410687: 4.6402441626852405e-05,
#  70160230: 1.2662612089271895e-06,
#  17217640: 0.0001503204216260688,
#  14936377: 0.00040690791857699195,
#  8255122: 8.104493897101074e-06,
#  24244836: 0.000206786902170342,
#  7429892: 0.0010276283666697732,
#  45957677: 1.2345676911479738e-08,
#  104585489: 0.00014718172442924145,
#  93714983: 0.0003633646546085164,
#  15234407: 0.013660878102305265,
#  104989762: 0.002716227631637186,
#  17384099: 0.0011075480576390549,
#  15431856: 6.31655879079362e-05,
#  15820660: 0.0003104904628231384,
#  18720204: 6.489142641688836e-05,
#  1435461: 0.0006908886828089426,
#  344776030: 0.00028952102368921454,
#  216366465: 1.645067023696195e-05,
#  158283753: 6.030529750226215e-07,
#  266464616: 5.697664587078746e-05,
#  12040102: 2.4732634431461028e-06,
#  15292446: 6.036360032567792e-06,
#  11348282: 0.0024561301604475584,
#  90746337: 2.2803818970664588e-05,
#  14091091: 0.0008667738190873233,
#  117017147: 4.073761380849746e-05,
#  244082406: 1.6184655660183593e-05,
#  15473958: 0.007515263722771014,
#  423745970: 1.9818649187049522e-08,
#  21179815: 3.7875983784768133e-07,
#  518403776: 0.0001675329813240318,
#  256889809: 0.00015428661013220014,
#  8623332: 4.5410417385119796e-06,
#  31401966: 5.186050116486388e-06,
#  14807898: 0.00039327486858916987,
#  14647570: 0.0024596089708206733,
#  274663230: 3.8531305067713804e-07,
#  208442526: 2.404951937368702e-05,
#  205195655: 0.00011378741693125367,
#  474423064: 3.5977038488767286e-07,
#  6408382: 2.2209652031504215e-05,
#  19816089: 2.3881872836012893e-07,
#  277375017: 1.0508103910198502e-05,
#  16363491: 0.000659037423947206,
#  51274038: 5.317221599441551e-07,
#  42380766: 5.423831485391705e-07,
#  277889424: 1.8172243569151633e-07,
#  99851285: 7.970229357827366e-06,
#  15110431: 0.0004739025110426236,
#  4620451: 0.030797572943962594,
#  131663151: 3.165342420464052e-05,
#  19384258: 7.80526231522719e-05,
#  137320881: 6.870870569026426e-05,
#  403339965: 2.22906252090215e-06,
#  19725644: 0.04530099288567686,
#  21808052: 2.211815722166538e-05,
#  174784400: 0.000174696697325029,
#  523340129: 2.686018895605727e-09,
#  222178782: 1.7289352745894493e-06,
#  277510682: 6.033587951748443e-06,
#  71502330: 2.5895217914208733e-07,
#  437806648: 1.7997055092811017e-06,
#  234343491: 0.0,
#  225096128: 0.0,
#  18700629: 4.444130476137507e-08,
#  20950208: 0.001265097712560529,
#  132249368: 9.151466800461503e-05,
#  16265412: 0.00046933875926982423,
#  41494136: 4.435303203191386e-05,
#  17176990: 1.9532486862635238e-05,
#  114115460: 0.0012918828218271606,
#  14743923: 4.480059013847939e-05,
#  268479669: 0.00027948239120651787,
#  2260771: 0.0009158270086449755,
#  16264063: 4.5368753282347994e-05,
#  22169313: 3.727472675802093e-05,
#  28889701: 9.129519147083523e-05,
#  20567578: 0.00015419089390094593,
#  14239780: 0.00015568198722643457,
#  15775181: 6.386569821076607e-05,
#  14456842: 0.0008063957018894695,
#  207936757: 0.0006003901199603763,
#  7668432: 1.7884379848932632e-06,
#  61336370: 0.0009205669581217985,
#  3359851: 0.15443758920551148,
#  243370113: 4.341383054779278e-05,
#  142001754: 1.121772822733604e-05,
#  175624200: 0.004646742392999157,
#  29206754: 2.686018895605727e-08,
#  19136295: 8.435863586368848e-07,
#  347466350: 0.0002720895016068049,
#  7098022: 0.0013453706273126697,
#  25071725: 9.057159605399786e-05,
#  256286568: 6.729506457945516e-07,
#  54319516: 0.00013104129020640988,
#  26553971: 3.581358527474302e-08,
#  208221645: 0.0,
#  4219131: 0.0001312768939640499,
#  16507381: 7.9816285068318e-08,
#  20621747: 1.2443706480543627e-06,
#  18742444: 0.0007119052473960628,
#  263352652: 3.4835136975896423e-06,
#  189234283: 0.00020831855554573865,
#  49666201: 2.755803600521736e-07,
#  34068984: 0.00025754975608632277,
#  369130833: 4.379800341740074e-06,
#  50393960: 0.009223752786743387,
#  14110133: 1.4127016993703735e-05,
#  14484504: 1.4337188255379738e-05,
#  117533865: 3.9553614399910355e-05,
#  350072433: 0.0,
#  34662645: 0.0001418894696642117,
#  14192988: 6.605858568050278e-05,
#  17738564: 2.6308680327450936e-05,
#  19663597: 5.2193106677253124e-05,
#  44177692: 0.0004544882000273334,
#  42579112: 0.00012027852998747475,
#  63273064: 0.0015681477262615947,
#  76774950: 0.0001680574312509756,
#  245076474: 0.0006114372338114793,
#  236719823: 1.8689368203730147e-05,
#  17064514: 0.0,
#  20106337: 8.079453744878111e-07,
#  40364293: 0.0,
#  248992493: 0.0,
#  17910878: 0.0004449121698681326,
#  14219826: 2.2638719418366103e-05,
#  283612037: 0.0,
#  166729867: 4.1561388568731976e-07,
#  41648744: 8.958895947874137e-08,
#  24109979: 0.0017783593904026397,
#  59378077: 2.9605897160454234e-07,
#  823860: 8.136976327296761e-07,
#  190752867: 4.40477123402178e-08,
#  341849215: 0.0,
#  304794994: 3.581358527474302e-08,
#  18208354: 5.7211905280452515e-05,
#  30034583: 0.0,
#  24563388: 0.0,
#  64209144: 0.0,
#  52422878: 3.581358527474302e-08,
#  36803580: 0.0,
#  29758446: 0.0,
#  16565797: 0.0,
#  19490867: 0.0,
#  105429988: 0.0,
#  93750955: 4.380176256269764e-07,
#  563031699: 4.5784300318978077e-07,
#  130340054: 2.817121598396776e-06,
#  487367041: 2.3073868762004643e-06,
#  107381955: 4.712730976678094e-07,
#  215824411: 2.1977550024192297e-07,
#  207878118: 0.00016989267424997965,
#  390455433: 4.2856681840169704e-07,
#  85891683: 0.0016112854661217743,
#  130357109: 2.3885547799950793e-06,
#  133929572: 4.712730976678094e-07,
#  304774444: 1.8589946802359617e-06,
#  18142375: 7.372014474220985e-06,
#  1294741: 3.2981287834863686e-05,
#  16139649: 1.9560509691134085e-06,
#  17363890: 1.152762754255068e-06,
#  19344585: 9.838682866647254e-07,
#  1002351: 1.20346224416271e-06,
#  19346439: 1.56551084737928e-06,
#  14085096: 2.7637228256784543e-06,
#  104203233: 1.020689227677363e-06,
#  9142362: 9.28062073653989e-08,
#  26985345: 3.725760859893989e-06,
#  33852508: 5.970069584460467e-07,
#  25702003: 1.1958923634743912e-06,
#  85794542: 4.850139284595005e-07,
#  56169454: 2.1027268551999437e-06,
#  25995437: 6.050493866647293e-06,
#  22021978: 6.196588435361168e-06,
#  58836363: 5.43166575804719e-07,
#  88722311: 1.7916912670823887e-06,
#  9442262: 5.619383869359666e-08,
#  87652742: 6.906905731557583e-08,
#  18874097: 1.352208153790772e-06,
#  14190551: 9.15089753453324e-06,
#  41351472: 3.439440546560077e-07,
#  465973: 3.0146786492198034e-06,
#  21697211: 1.0863454200005384e-07,
#  149075605: 0.0,
#  16133363: 2.652954912833418e-06,
#  24185807: 1.3430094478028634e-08,
#  61228125: 7.156470624527198e-07,
#  89479311: 0.0,
#  123567601: 0.0,
#  86337034: 1.4837056756679253e-08,
#  107017176: 1.0066892622328022e-06,
#  84563846: 8.967158627090424e-07,
#  39055030: 4.154375891870191e-07,
#  82406734: 6.502993115677022e-08,
#  37883682: 1.1309553244655691e-08,
#  30869029: 0.0,
#  24160143: 0.0,
#  19722805: 0.0,
#  18186507: 0.0,
#  247200654: 0.0,
#  14796276: 2.014514171704295e-08,
#  9568572: 0.0,
#  6143852: 0.0,
#  ...}

# %%
betweenness_centrality = nx.centrality.betweenness_centrality(G)
#Top 5 nodos con máyor centralidad de intermediación
(sorted(betweenness_centrality.items(), key=lambda item: item[1], reverse=True))[:5]
# Out:
# [(6207392, 0.1725645640056724),
#  (3359851, 0.15443758920551148),
#  (783214, 0.0975291202117271),
#  (41716273, 0.09272687817377762),
#  (17093617, 0.09073724589851986)]

# %%
# Visulizar histograma de centralidad de intermediación
plt.figure(figsize=(15, 8))
plt.hist(betweenness_centrality.values(), bins=20)
plt.xticks(ticks=[0, 0.02, 0.1])
plt.title("Histograma Centralidad de Intermediación", fontdict={"size": 20}, loc="center")
plt.xlabel("Centralidad de Intermediación", fontdict={"size": 12})
plt.ylabel("Conteo", fontdict={"size": 12})
# Out:
# Text(0, 0.5, 'Conteo')

# %% [markdown]
# Solo dos nodos cuentan con un valor mayor de 0.1 de centralidad de intermediación. Esto significa que la mayoría de nodos no participan como puente en el camino mas corto entre todos los nodos del grafo. El top 5 identificado logra tener la mayor influencia sobre la red debido a que participan en la interacción de un número mayor de nodos y vecindades.

# %%
# Visualizar los nodos con mayor centralidad de intermediación
node_size = [v * 1200 for v in betweenness_centrality.values()]
plt.figure(figsize=(15, 8))
nx.draw_networkx(G, pos=pos, node_size=node_size, with_labels=False, width=0.10)
plt.axis("off")
# Out:
# (np.float64(-0.6459476724267006),
#  np.float64(1.1564022675156593),
#  np.float64(-1.0558947339653968),
#  np.float64(0.7013561144471169))

# %% [markdown]
# ###Centralidad de cercanía

# %%
closeness_centrality = nx.centrality.closeness_centrality(G)  # save results in a variable to use again
(sorted(closeness_centrality.items(), key=lambda item: item[1], reverse=True))[:5]
# Out:
# [(3359851, 0.3174907000782523),
#  (15234657, 0.2989200839846593),
#  (48485771, 0.2947102540271258),
#  (7860742, 0.293730499193259),
#  (15666380, 0.2907448655999966)]

# %%
1 / closeness_centrality[3359851]
# Out:
# 3.149698557323187

# %%
plt.figure(figsize=(15, 8))
plt.hist(closeness_centrality.values(), bins=60)
plt.title("Histograma de Centralidad de Cercanía ", fontdict={"size": 20}, loc="center")
plt.xlabel("Centralidad de Cercanía", fontdict={"size": 12})
plt.ylabel("Conteo", fontdict={"size": 12})
# Out:
# Text(0, 0.5, 'Conteo')

# %% [markdown]
# La mayoría de nodos tienen un valor menor de 0.3 de centralidad de cercanía. Esto significa que la mayoría de nodos no participan no se encuentran cercanos a los demás. El top 5 identificado logra tener la mayor influencia sobre la red debido a que se encuentran con mayor cercanía al resto de nodos del grafo.

# %%
node_size = [
    v * 50 for v in closeness_centrality.values()
]  # set up nodes size for a nice graph representation
plt.figure(figsize=(15, 8))
nx.draw_networkx(G, pos=pos, node_size=node_size, with_labels=False, width=0.10)
plt.axis("off")
# Out:
# (np.float64(-0.6459476724267006),
#  np.float64(1.1564022675156593),
#  np.float64(-1.0558947339653968),
#  np.float64(0.7013561144471169))

# %% [markdown]
# ###Centralidad de Eigenvector

# %%
eigenvector_centrality = nx.centrality.eigenvector_centrality(G)  # save results in a variable to use again
(sorted(eigenvector_centrality.items(), key=lambda item: item[1], reverse=True))[:5]
# Out:
# [(40981798, 0.15363590744821665),
#  (43003845, 0.1507372702636457),
#  (22462180, 0.14898138833635383),
#  (34428380, 0.14836888505482648),
#  (153226312, 0.11747403879993272)]

# %% [markdown]
# El nodo 40981798 tiene la centralidad de vector propio más alta con 0.15. Este nodo también es un nodo destacado y seguramente puede considerarse el nodo más importante de esta red en términos de influencia general en toda la red.

# %%
high_eigenvector_centralities = (
    sorted(eigenvector_centrality.items(), key=lambda item: item[1], reverse=True)
)[
    1:5
]  # 2nd to 10th nodes with heighest eigenvector centralities
high_eigenvector_nodes = [
    tuple[0] for tuple in high_eigenvector_centralities
]
neighbors_eigen = [n for n in G.neighbors(40981798)]  # list with all nodes connected to
all(
    item in neighbors_eigen for item in high_eigenvector_nodes
)  # check if items in list high_eigenvector_nodes exist in list neighbors
# Out:
# True

# %%
plt.figure(figsize=(15, 8))
plt.hist(eigenvector_centrality.values(), bins=60)
plt.xticks(ticks=[0, 0.01, 0.02, 0.04, 0.06, 0.08])  # set the x axis ticks
plt.title("Histograma de Centralidad de Eigenvector", fontdict={"size": 20}, loc="center")
plt.xlabel("Centralidad de Eigenvector", fontdict={"size": 12})
plt.ylabel("Conteo", fontdict={"size": 12})
# Out:
# Text(0, 0.5, 'Conteo')

# %%
node_size = [
    v * 4000 for v in eigenvector_centrality.values()
]  # set up nodes size for a nice graph representation
plt.figure(figsize=(15, 8))
nx.draw_networkx(G, pos=pos, node_size=node_size, with_labels=False, width=0.10)
plt.axis("off")
# Out:
# (np.float64(-0.6459476724267006),
#  np.float64(1.1564022675156593),
#  np.float64(-1.0558947339653968),
#  np.float64(0.7013561144471169))

# %% [markdown]
# ###Métricas de Resiliencia

# %%
nx.degree_assortativity_coefficient(G)
# Out:
# 0.07572773506976808

# %% [markdown]
# El valor de asortatividad es cercano a 0 por lo que se observa una asortatividad neutral. Esto significa que no hay una preferencia en como se conectan los nodos basado en sus grados.
#
# En nuestro problema de Twitter, observamos que no hay una tendencia específica en que usuarios con el mismo número de seguidores se sigan entre sí.
